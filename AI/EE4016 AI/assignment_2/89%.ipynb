# %% [markdown]
# # PyTorch Convolutional Neural Network (CNN) With CIFAR-10 Color Image Dataset
#
# In this example, we demonstrate how to train a CNN model (aka ConvNet)  to classify images from the CIFAR-10 dataset. With the nature of CNN can handle spatial data of images and video, the RGB-color images  of CIFAR-10 can be directly use as input to the model.
#
# <img src='https://www.ee.cityu.edu.hk/~lmpo/ee5438/images/cnn_cifar10.png'>
#
#
# The CIFAR-10 dataset is a widely used collection of images that is commonly used to train machine learning and computer vision algorithms
#
# - It consists of 60,000 32x32 color images in 10 different classes
# - Each class contains 6,000 images, with 5,000 images for training and 1,000 images for testing
# - The 10 different classes in the CIFAR-10 dataset represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks
#
# The CIFAR-10 dataset can be split into training set, validation set, and test set in various ways. In this example, the way is to use 45,000 images for training, 5,000 images for validation, and 10,000 images for testing.
#
# <!-- <img src='https://corochann.com/wp-content/uploads/2021/09/cifar10_plot.png'> -->
#
#
# References:
#
# - https://github.com/nestorojeda/CIFAR-10-CNN

# %%
# Install the torchinfo package for showing the network architecture information
# !pip install torchinfo -qqq

# %%
# Import the necessary libraries for working with CIFART-10 dataset and PyTorch.
import torch
import torchvision
from torchvision import datasets,transforms
import torch.nn as nn
import torch.nn.functional as F
from torch import nn,optim,no_grad
from torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
from torchinfo import summary

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import pandas as pd
import numpy as np
import pickle
import sys
import time

# %%
# To configure the usage of a GPU (cuda) or MPS (Apple) if either of them is available
has_mps = torch.backends.mps.is_built()
device = "cuda" if torch.cuda.is_available() else "mps" if has_mps else "cpu"
print(f"Python versoin: {sys.version_info.major, sys.version_info.minor, sys.version_info.micro}")
print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")
# Out:
# Python versoin: (3, 11, 9)
# PyTorch version: 2.4.1+cu118
# Device: cuda

# %%
# Set seed for reproducibility
seed = 4016
torch.manual_seed(seed)

# %% [markdown]
# # Download CIFAR10 Dataset
#
# This code snippet helps us download the CIFAR-10 dataset, which is a popular dataset used for training and evaluating deep learning models. The dataset is divided into a training set and a test set.
#
# In deep learning, it's common to split the dataset into training, validation, and test sets. However, in this particular example, the validation set is not used. Instead, we only use the training set to train our model. The training set consists of 50,000 samples, and we use these samples to teach our model how to recognize and classify images.
#
# **During and after training, the model's performance is evaluated by the test set with 10,000 samples. The test set contains a separate set of samples that were not used to update the model's parameters during the training.** We use this test set to assess how well our trained model can generalize to new, unseen data.
#
# By creating DataLoaders, we can easily handle the downloading and loading of the training and test sets, making it convenient for us to train our deep learning model on the CIFAR-10 dataset.

# %%
# Define data transformations for the training and test sets
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    
    ])

test_transform = transforms.Compose([
     transforms.ToTensor(), # Convert images to tensors
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))]) # Normalize the image data

# Create the CIFAR10dataset for the training set with 50,000 images
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)

# Create the CIFAR10 dataset for the test set with 10,000 images (It is also used as validation set during the training)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

# Define the data loaders for the training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_set, batch_size=256, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=256, shuffle=False, num_workers=2)

# Define the classes for the CIFAR-10 dataset
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Visualize image for each class
#
# The first step in a classification task is to take a look at the data, make sure it is loaded in correctly, then make any initial observations about patterns in that data.

# %%
# Visualize training image for each class
sample_images = [train_set.data[np.asarray(train_set.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# ## Define the CNN Architecture
#
# The following code defines a class called CNN_Model which inherits from nn.Module. The network has 3 fully-connected layers:
#
# - In the first line, we use the "Conv2d" module to implement a convolutional neural network. The first parameter, 3, indicates that the input image is colored and in RGB format. If it were a grayscale image, we would use 1 instead.
#
# - The number 32 represents the initial output channels, and in the next Conv2d layer, we would use 32 as the input channels and 64 as the output channels.
#
# - The third parameter in the first line is the kernel size, which determines the size of the filters used. The last parameter is for padding, which helps maintain the spatial dimensions of the input.
#
# After each Conv2d layer, we apply an activation function, specifically the Rectified Linear Unit (ReLU). Following two Conv2d layers, we perform a max-pooling operation with a 2x2 size. The resulting values are then batch normalized to ensure stability and avoid internal covariate shift. These operations are repeated with additional layers to make the network deeper and reduce the size of the data. Finally, we flatten the layer to create a linear layer that maps the values to 10 outputs. The probability of each neuron in these 10 outputs determines the class to which a particular image belongs, with the highest probability indicating the predicted class.

# %%
# Define the CNN Model

class CNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
    self.bn1 = nn.BatchNorm2d(64)
    self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
    self.bn2 = nn.BatchNorm2d(128)
    self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
    self.bn3 = nn.BatchNorm2d(256)
    self.pool = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(256 * 4 * 4, 1024)
    self.fc2 = nn.Linear(1024, 512)
    self.fc3 = nn.Linear(512, 10)
    self.dropout = nn.Dropout(0.5)

  def forward(self, x):
    x = self.pool(F.relu(self.bn1(self.conv1(x))))
    x = self.pool(F.relu(self.bn2(self.conv2(x))))
    x = self.pool(F.relu(self.bn3(self.conv3(x))))
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    x = self.dropout(x)
    x = F.relu(self.fc2(x))
    x = self.dropout(x)
    x = self.fc3(x)
    return x

# %%
model = create_resnet18()

# %%
summary(model=model, input_size=(1, 3, 32, 32), col_width=15,
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        row_settings=['var_names'], verbose=0)
# Out:
# ====================================================================================================
# Layer (type (var_name))                  Input Shape     Output Shape    Param #         Trainable
# ====================================================================================================
# CNN (CNN)                                [1, 3, 32, 32]  [1, 10]         --              True
# ├─Conv2d (conv1)                         [1, 3, 32, 32]  [1, 64, 32, 32] 1,792           True
# ├─BatchNorm2d (bn1)                      [1, 64, 32, 32] [1, 64, 32, 32] 128             True
# ├─MaxPool2d (pool)                       [1, 64, 32, 32] [1, 64, 16, 16] --              --
# ├─Conv2d (conv2)                         [1, 64, 16, 16] [1, 128, 16, 16] 73,856          True
# ├─BatchNorm2d (bn2)                      [1, 128, 16, 16] [1, 128, 16, 16] 256             True
# ├─MaxPool2d (pool)                       [1, 128, 16, 16] [1, 128, 8, 8]  --              --
# ├─Conv2d (conv3)                         [1, 128, 8, 8]  [1, 256, 8, 8]  295,168         True
# ├─BatchNorm2d (bn3)                      [1, 256, 8, 8]  [1, 256, 8, 8]  512             True
# ├─MaxPool2d (pool)                       [1, 256, 8, 8]  [1, 256, 4, 4]  --              --
# ├─Linear (fc1)                           [1, 4096]       [1, 1024]       4,195,328       True
# ├─Dropout (dropout)                      [1, 1024]       [1, 1024]       --              --
# ├─Linear (fc2)                           [1, 1024]       [1, 512]        524,800         True
# ├─Dropout (dropout)                      [1, 512]        [1, 512]        --              --
# ├─Linear (fc3)                           [1, 512]        [1, 10]         5,130           True
# ====================================================================================================
# Total params: 5,096,970
# Trainable params: 5,096,970
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 44.36
# ====================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.85
# Params size (MB): 20.39
# Estimated Total Size (MB): 22.25
# ====================================================================================================

# %% [markdown]
# ## Training the Network
#
# The steps for training/learning from a batch of data are described in the comments below:
#
# Clear the gradients of all optimized variables
# Forward pass: compute predicted outputs by passing inputs to the model
# Calculate the loss
# Backward pass: compute gradient of the loss with respect to model parameters
# Perform a single optimization step (parameter update)
# Update average training loss
# The following loop trains for 50 epochs; take a look at how the values for the training loss decrease over time. We want it to decrease while also avoiding overfitting the training data.

# %%
# Create a Models folder to store the checkpoints
# !mkdir Models
# Out:
# �l�ؿ����ɮ� Models �w�g�s�b�C

# %% [markdown]
# ## Specify Loss Function and Optimizer
# It's recommended that you use cross-entropy loss for classification. If you look at the documentation (linked above), you can see that PyTorch's cross entropy function applies a softmax funtion to the output layer and then calculates the log loss.

# %%
# Specify Loss/Cost function
criterion = nn.CrossEntropyLoss()

# Specify optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# optimizer = optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
# optimizer = optim.SGD(model.parameters(), lr=0.01)

# Specify Learning Rate Scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True, min_lr=0)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=5, verbose=True)
# Out:
# g:\python\ee4016 ai\assignment_1\venv\Lib\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
EPOCHS = 200

loss_hist, acc_hist = [], []  # Lists to store training loss and accuracy
loss_hist_test, acc_hist_test = [], []  # Lists to store validation loss and accuracy

model.to(device)  # Move the model to the specified device (e.g., GPU)

print("Training was started.\n")

for epoch in range(1, EPOCHS + 1):
    time_ckpt = time.time()
    print("EPOCH:", epoch, end=" ")
    running_loss = 0.0
    correct = 0

    # Training loop
    for data in train_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)

        optimizer.zero_grad()  # Clear the gradients
        outputs = model(batch)  # Forward pass
        loss = criterion(outputs, labels)  # Compute the loss
        loss.backward()  # Backward pass (compute gradients)
        optimizer.step()  # Update the model's parameters

        # Compute training statistics
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

    avg_loss = running_loss / len(train_set)  # Average training loss for the epoch
    avg_acc = correct / len(train_set)  # Average training accuracy for the epoch
    loss_hist.append(avg_loss)
    acc_hist.append(avg_acc)

    # Validation statistics
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        loss_test = 0.0
        correct_test = 0

        # Validation loop
        for data in test_loader:
            batch, labels = data
            batch, labels = batch.to(device), labels.to(device)
            outputs = model(batch)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            correct_test += (predicted == labels).sum().item()
            loss_test += loss.item()

        avg_loss_test = loss_test / len(test_set)  # Average validation loss for the epoch
        avg_acc_test = correct_test / len(test_set)  # Average validation accuracy for the epoch
        loss_hist_test.append(avg_loss_test)
        acc_hist_test.append(avg_acc_test)


    model.train()  # Set the model back to training mode

    scheduler.step(avg_loss_test) # Check the scheduler for updating the learning rate

    # Save the model at the end of each epoch
    with open("Models/lenet5_model_{}.pth".format(epoch), "wb") as f:
        model.eval()
        pickle.dump(model, f)
        model.train()

    print("Train Loss: {:.3f}".format(avg_loss * 100), end=" ")
    print("Test Loss: {:.3f}".format(avg_loss_test * 100), end=" ")
    print("Train Accuracy: {:.2f}%".format(avg_acc * 100), end=" ")
    print("Test Accuracy: {:.2f}%".format(avg_acc_test * 100), end=" ")
    print("Time: {:.2f}s".format(time.time() - time_ckpt), end=" \n")
# Out:
# Training was started.
#
# EPOCH: 1 Train Loss: 0.694 Test Loss: 0.560 Train Accuracy: 33.77% Test Accuracy: 48.25% Time: 21.55s
# EPOCH: 2 Train Loss: 0.567 Test Loss: 0.466 Train Accuracy: 46.98% Test Accuracy: 57.72% Time: 22.28s
# EPOCH: 3 Train Loss: 0.508 Test Loss: 0.410 Train Accuracy: 52.94% Test Accuracy: 63.26% Time: 22.39s
# EPOCH: 4 Train Loss: 0.473 Test Loss: 0.381 Train Accuracy: 56.86% Test Accuracy: 66.55% Time: 22.06s
# EPOCH: 5 Train Loss: 0.441 Test Loss: 0.374 Train Accuracy: 60.24% Test Accuracy: 66.57% Time: 22.10s
# EPOCH: 6 Train Loss: 0.416 Test Loss: 0.355 Train Accuracy: 62.35% Test Accuracy: 69.16% Time: 21.89s
# EPOCH: 7 Train Loss: 0.401 Test Loss: 0.341 Train Accuracy: 64.11% Test Accuracy: 70.65% Time: 21.77s
# EPOCH: 8 Train Loss: 0.385 Test Loss: 0.333 Train Accuracy: 65.95% Test Accuracy: 70.34% Time: 22.58s
# EPOCH: 9 Train Loss: 0.371 Test Loss: 0.311 Train Accuracy: 67.31% Test Accuracy: 72.61% Time: 22.50s
# EPOCH: 10 Train Loss: 0.353 Test Loss: 0.299 Train Accuracy: 68.77% Test Accuracy: 74.89% Time: 22.08s
# EPOCH: 11 Train Loss: 0.346 Test Loss: 0.275 Train Accuracy: 69.79% Test Accuracy: 75.93% Time: 21.88s
# EPOCH: 12 Train Loss: 0.332 Test Loss: 0.280 Train Accuracy: 70.76% Test Accuracy: 75.70% Time: 21.47s
# EPOCH: 13 Train Loss: 0.325 Test Loss: 0.271 Train Accuracy: 71.56% Test Accuracy: 77.59% Time: 22.19s
# EPOCH: 14 Train Loss: 0.319 Test Loss: 0.270 Train Accuracy: 72.19% Test Accuracy: 76.02% Time: 22.50s
# EPOCH: 15 Train Loss: 0.306 Test Loss: 0.267 Train Accuracy: 73.32% Test Accuracy: 77.40% Time: 22.46s
# EPOCH: 16 Train Loss: 0.299 Test Loss: 0.260 Train Accuracy: 73.83% Test Accuracy: 77.64% Time: 22.35s
# EPOCH: 17 Train Loss: 0.294 Test Loss: 0.239 Train Accuracy: 74.47% Test Accuracy: 79.88% Time: 20.82s
# EPOCH: 18 Train Loss: 0.287 Test Loss: 0.245 Train Accuracy: 75.04% Test Accuracy: 78.75% Time: 20.92s
# EPOCH: 19 Train Loss: 0.277 Test Loss: 0.234 Train Accuracy: 75.91% Test Accuracy: 80.33% Time: 21.26s
# EPOCH: 20 Train Loss: 0.273 Test Loss: 0.254 Train Accuracy: 76.31% Test Accuracy: 77.47% Time: 21.18s
# EPOCH: 21 Train Loss: 0.269 Test Loss: 0.226 Train Accuracy: 76.62% Test Accuracy: 80.93% Time: 20.80s
# EPOCH: 22 Train Loss: 0.265 Test Loss: 0.239 Train Accuracy: 77.13% Test Accuracy: 79.31% Time: 21.31s
# EPOCH: 23 Train Loss: 0.256 Test Loss: 0.247 Train Accuracy: 77.90% Test Accuracy: 79.81% Time: 20.65s
# EPOCH: 24 Train Loss: 0.252 Test Loss: 0.204 Train Accuracy: 78.26% Test Accuracy: 82.71% Time: 21.19s
# EPOCH: 25 Train Loss: 0.246 Test Loss: 0.208 Train Accuracy: 78.72% Test Accuracy: 82.21% Time: 22.73s
# EPOCH: 26 Train Loss: 0.244 Test Loss: 0.197 Train Accuracy: 78.95% Test Accuracy: 83.04% Time: 21.53s
# EPOCH: 27 Train Loss: 0.239 Test Loss: 0.200 Train Accuracy: 79.27% Test Accuracy: 82.54% Time: 23.33s
# EPOCH: 28 Train Loss: 0.235 Test Loss: 0.194 Train Accuracy: 79.75% Test Accuracy: 83.50% Time: 21.72s
# EPOCH: 29 Train Loss: 0.230 Test Loss: 0.198 Train Accuracy: 80.43% Test Accuracy: 82.67% Time: 22.50s
# EPOCH: 30 Train Loss: 0.229 Test Loss: 0.199 Train Accuracy: 80.22% Test Accuracy: 82.68% Time: 22.75s
# EPOCH: 31 Train Loss: 0.221 Test Loss: 0.206 Train Accuracy: 81.11% Test Accuracy: 82.38% Time: 22.87s
# EPOCH: 32 Train Loss: 0.222 Test Loss: 0.189 Train Accuracy: 80.99% Test Accuracy: 84.12% Time: 22.40s
# EPOCH: 33 Train Loss: 0.218 Test Loss: 0.191 Train Accuracy: 81.39% Test Accuracy: 84.03% Time: 21.96s
# EPOCH: 34 Train Loss: 0.213 Test Loss: 0.181 Train Accuracy: 81.94% Test Accuracy: 84.63% Time: 22.38s
# EPOCH: 35 Train Loss: 0.210 Test Loss: 0.204 Train Accuracy: 82.03% Test Accuracy: 82.33% Time: 23.17s
# EPOCH: 36 Train Loss: 0.210 Test Loss: 0.194 Train Accuracy: 82.15% Test Accuracy: 83.21% Time: 22.46s
# EPOCH: 37 Train Loss: 0.206 Test Loss: 0.192 Train Accuracy: 82.26% Test Accuracy: 83.43% Time: 27.25s
# EPOCH: 38 Train Loss: 0.204 Test Loss: 0.187 Train Accuracy: 82.38% Test Accuracy: 83.97% Time: 25.98s
# EPOCH: 39 Train Loss: 0.202 Test Loss: 0.173 Train Accuracy: 82.66% Test Accuracy: 85.15% Time: 23.21s
# EPOCH: 40 Train Loss: 0.202 Test Loss: 0.178 Train Accuracy: 82.73% Test Accuracy: 84.99% Time: 20.90s
# EPOCH: 41 Train Loss: 0.195 Test Loss: 0.172 Train Accuracy: 83.21% Test Accuracy: 85.43% Time: 22.41s
# EPOCH: 42 Train Loss: 0.194 Test Loss: 0.189 Train Accuracy: 83.38% Test Accuracy: 84.10% Time: 22.31s
# EPOCH: 43 Train Loss: 0.192 Test Loss: 0.177 Train Accuracy: 83.46% Test Accuracy: 85.12% Time: 22.95s
# EPOCH: 44 Train Loss: 0.191 Test Loss: 0.175 Train Accuracy: 83.53% Test Accuracy: 85.41% Time: 22.58s
# EPOCH: 45 Train Loss: 0.189 Test Loss: 0.178 Train Accuracy: 83.80% Test Accuracy: 85.08% Time: 22.69s
# EPOCH: 46 Train Loss: 0.190 Test Loss: 0.167 Train Accuracy: 83.70% Test Accuracy: 85.79% Time: 22.12s
# EPOCH: 47 Train Loss: 0.186 Test Loss: 0.172 Train Accuracy: 83.77% Test Accuracy: 85.10% Time: 22.84s
# EPOCH: 48 Train Loss: 0.184 Test Loss: 0.167 Train Accuracy: 84.22% Test Accuracy: 85.84% Time: 22.15s
# EPOCH: 49 Train Loss: 0.184 Test Loss: 0.176 Train Accuracy: 84.37% Test Accuracy: 85.21% Time: 21.09s
# EPOCH: 50 Train Loss: 0.183 Test Loss: 0.164 Train Accuracy: 84.36% Test Accuracy: 86.34% Time: 21.10s
# EPOCH: 51 Train Loss: 0.180 Test Loss: 0.175 Train Accuracy: 84.50% Test Accuracy: 85.44% Time: 20.78s
# EPOCH: 52 Train Loss: 0.179 Test Loss: 0.185 Train Accuracy: 84.47% Test Accuracy: 84.61% Time: 19.84s
# EPOCH: 53 Train Loss: 0.179 Test Loss: 0.168 Train Accuracy: 84.79% Test Accuracy: 85.82% Time: 20.48s
# EPOCH: 54 Train Loss: 0.176 Test Loss: 0.161 Train Accuracy: 85.06% Test Accuracy: 86.50% Time: 19.93s
# EPOCH: 55 Train Loss: 0.175 Test Loss: 0.168 Train Accuracy: 85.18% Test Accuracy: 86.22% Time: 19.97s
# EPOCH: 56 Train Loss: 0.174 Test Loss: 0.169 Train Accuracy: 85.01% Test Accuracy: 85.85% Time: 21.45s
# EPOCH: 57 Train Loss: 0.173 Test Loss: 0.168 Train Accuracy: 85.15% Test Accuracy: 85.92% Time: 21.89s
# EPOCH: 58 Train Loss: 0.169 Test Loss: 0.163 Train Accuracy: 85.68% Test Accuracy: 86.61% Time: 22.53s
# EPOCH: 59 Train Loss: 0.171 Test Loss: 0.161 Train Accuracy: 85.32% Test Accuracy: 86.59% Time: 22.34s
# EPOCH: 60 Train Loss: 0.169 Test Loss: 0.160 Train Accuracy: 85.46% Test Accuracy: 86.66% Time: 22.06s
# EPOCH: 61 Train Loss: 0.168 Test Loss: 0.160 Train Accuracy: 85.41% Test Accuracy: 86.83% Time: 21.69s
# EPOCH: 62 Train Loss: 0.167 Test Loss: 0.157 Train Accuracy: 85.69% Test Accuracy: 86.93% Time: 21.63s
# EPOCH: 63 Train Loss: 0.166 Test Loss: 0.159 Train Accuracy: 85.76% Test Accuracy: 87.07% Time: 22.06s
# EPOCH: 64 Train Loss: 0.164 Test Loss: 0.165 Train Accuracy: 86.04% Test Accuracy: 86.57% Time: 22.30s
# EPOCH: 65 Train Loss: 0.164 Test Loss: 0.168 Train Accuracy: 85.94% Test Accuracy: 86.00% Time: 22.45s
# EPOCH: 66 Train Loss: 0.160 Test Loss: 0.161 Train Accuracy: 86.23% Test Accuracy: 86.56% Time: 22.49s
# EPOCH: 67 Train Loss: 0.162 Test Loss: 0.157 Train Accuracy: 86.17% Test Accuracy: 87.26% Time: 22.08s
# EPOCH: 68 Train Loss: 0.161 Test Loss: 0.172 Train Accuracy: 86.31% Test Accuracy: 85.61% Time: 22.33s
# EPOCH: 69 Train Loss: 0.158 Test Loss: 0.163 Train Accuracy: 86.59% Test Accuracy: 86.39% Time: 22.30s
# EPOCH: 70 Train Loss: 0.158 Test Loss: 0.163 Train Accuracy: 86.35% Test Accuracy: 86.75% Time: 22.38s
# EPOCH: 71 Train Loss: 0.158 Test Loss: 0.171 Train Accuracy: 86.62% Test Accuracy: 86.11% Time: 22.08s
# EPOCH: 72 Train Loss: 0.160 Test Loss: 0.189 Train Accuracy: 86.34% Test Accuracy: 84.85% Time: 22.10s
# EPOCH: 73 Train Loss: 0.158 Test Loss: 0.174 Train Accuracy: 86.42% Test Accuracy: 85.58% Time: 22.41s
# EPOCH: 74 Train Loss: 0.139 Test Loss: 0.144 Train Accuracy: 88.15% Test Accuracy: 88.05% Time: 22.43s
# EPOCH: 75 Train Loss: 0.129 Test Loss: 0.143 Train Accuracy: 88.96% Test Accuracy: 88.50% Time: 22.94s
# EPOCH: 76 Train Loss: 0.127 Test Loss: 0.140 Train Accuracy: 89.24% Test Accuracy: 88.59% Time: 22.61s
# EPOCH: 77 Train Loss: 0.124 Test Loss: 0.142 Train Accuracy: 89.37% Test Accuracy: 88.59% Time: 22.15s
# EPOCH: 78 Train Loss: 0.121 Test Loss: 0.142 Train Accuracy: 89.53% Test Accuracy: 88.47% Time: 22.50s
# EPOCH: 79 Train Loss: 0.120 Test Loss: 0.141 Train Accuracy: 89.71% Test Accuracy: 88.73% Time: 22.24s
# EPOCH: 80 Train Loss: 0.117 Test Loss: 0.140 Train Accuracy: 89.93% Test Accuracy: 88.94% Time: 22.63s
# EPOCH: 81 Train Loss: 0.115 Test Loss: 0.140 Train Accuracy: 90.24% Test Accuracy: 88.96% Time: 22.56s
# EPOCH: 82 Train Loss: 0.116 Test Loss: 0.140 Train Accuracy: 90.15% Test Accuracy: 88.76% Time: 22.27s
# EPOCH: 83 Train Loss: 0.115 Test Loss: 0.138 Train Accuracy: 90.19% Test Accuracy: 89.05% Time: 22.04s
# EPOCH: 84 Train Loss: 0.112 Test Loss: 0.140 Train Accuracy: 90.43% Test Accuracy: 89.19% Time: 21.47s
# EPOCH: 85 Train Loss: 0.112 Test Loss: 0.140 Train Accuracy: 90.32% Test Accuracy: 88.92% Time: 23.76s
# EPOCH: 86 Train Loss: 0.111 Test Loss: 0.142 Train Accuracy: 90.54% Test Accuracy: 89.10% Time: 22.67s
# EPOCH: 87 Train Loss: 0.111 Test Loss: 0.139 Train Accuracy: 90.59% Test Accuracy: 89.02% Time: 22.40s
# EPOCH: 88 Train Loss: 0.111 Test Loss: 0.139 Train Accuracy: 90.58% Test Accuracy: 89.14% Time: 21.91s
# EPOCH: 89 Train Loss: 0.111 Test Loss: 0.140 Train Accuracy: 90.72% Test Accuracy: 89.06% Time: 21.90s
# EPOCH: 90 Train Loss: 0.110 Test Loss: 0.139 Train Accuracy: 90.65% Test Accuracy: 89.06% Time: 22.64s
# EPOCH: 91 Train Loss: 0.108 Test Loss: 0.138 Train Accuracy: 90.67% Test Accuracy: 89.11% Time: 22.54s
# EPOCH: 92 Train Loss: 0.107 Test Loss: 0.139 Train Accuracy: 90.84% Test Accuracy: 89.12% Time: 22.21s
# EPOCH: 93 Train Loss: 0.106 Test Loss: 0.140 Train Accuracy: 90.79% Test Accuracy: 89.20% Time: 20.93s
# EPOCH: 94 Train Loss: 0.105 Test Loss: 0.141 Train Accuracy: 90.95% Test Accuracy: 88.91% Time: 20.41s
# EPOCH: 95 Train Loss: 0.105 Test Loss: 0.139 Train Accuracy: 90.99% Test Accuracy: 89.26% Time: 20.13s
# EPOCH: 96 Train Loss: 0.102 Test Loss: 0.139 Train Accuracy: 91.23% Test Accuracy: 89.18% Time: 20.03s
# EPOCH: 97 Train Loss: 0.103 Test Loss: 0.139 Train Accuracy: 91.07% Test Accuracy: 89.27% Time: 20.03s
# EPOCH: 98 Train Loss: 0.102 Test Loss: 0.139 Train Accuracy: 91.14% Test Accuracy: 89.22% Time: 19.90s
# EPOCH: 99 Train Loss: 0.102 Test Loss: 0.139 Train Accuracy: 91.41% Test Accuracy: 89.16% Time: 20.09s
# EPOCH: 100 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.18% Test Accuracy: 89.22% Time: 20.94s
# EPOCH: 101 Train Loss: 0.103 Test Loss: 0.139 Train Accuracy: 91.05% Test Accuracy: 89.41% Time: 22.87s
# EPOCH: 102 Train Loss: 0.103 Test Loss: 0.138 Train Accuracy: 91.27% Test Accuracy: 89.37% Time: 21.95s
# EPOCH: 103 Train Loss: 0.100 Test Loss: 0.139 Train Accuracy: 91.32% Test Accuracy: 89.26% Time: 21.86s
# EPOCH: 104 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.08% Test Accuracy: 89.25% Time: 21.91s
# EPOCH: 105 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.20% Test Accuracy: 89.29% Time: 22.18s
# EPOCH: 106 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.31% Test Accuracy: 89.31% Time: 21.99s
# EPOCH: 107 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.30% Test Accuracy: 89.38% Time: 21.69s
# EPOCH: 108 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.24% Test Accuracy: 89.43% Time: 20.70s
# EPOCH: 109 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.19% Test Accuracy: 89.31% Time: 22.06s
# EPOCH: 110 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.39% Test Accuracy: 89.41% Time: 21.24s
# EPOCH: 111 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.57% Test Accuracy: 89.26% Time: 22.28s
# EPOCH: 112 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.18% Test Accuracy: 89.29% Time: 22.10s
# EPOCH: 113 Train Loss: 0.099 Test Loss: 0.138 Train Accuracy: 91.47% Test Accuracy: 89.41% Time: 20.94s
# EPOCH: 114 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.28% Test Accuracy: 89.34% Time: 21.25s
# EPOCH: 115 Train Loss: 0.101 Test Loss: 0.139 Train Accuracy: 91.36% Test Accuracy: 89.22% Time: 22.05s
# EPOCH: 116 Train Loss: 0.103 Test Loss: 0.139 Train Accuracy: 91.16% Test Accuracy: 89.27% Time: 21.72s
# EPOCH: 117 Train Loss: 0.100 Test Loss: 0.139 Train Accuracy: 91.36% Test Accuracy: 89.25% Time: 20.67s
# EPOCH: 118 Train Loss: 0.101 Test Loss: 0.139 Train Accuracy: 91.35% Test Accuracy: 89.30% Time: 21.57s
# EPOCH: 119 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.28% Test Accuracy: 89.32% Time: 21.69s
# EPOCH: 120 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.17% Test Accuracy: 89.25% Time: 22.07s
# EPOCH: 121 Train Loss: 0.101 Test Loss: 0.139 Train Accuracy: 91.43% Test Accuracy: 89.24% Time: 21.79s
# EPOCH: 122 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.40% Test Accuracy: 89.31% Time: 22.02s
# EPOCH: 123 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.38% Test Accuracy: 89.18% Time: 22.07s
# EPOCH: 124 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.41% Test Accuracy: 89.40% Time: 21.98s
# EPOCH: 125 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.18% Test Accuracy: 89.30% Time: 21.98s
# EPOCH: 126 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.42% Test Accuracy: 89.33% Time: 21.33s
# EPOCH: 127 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.29% Test Accuracy: 89.32% Time: 21.70s
# EPOCH: 128 Train Loss: 0.102 Test Loss: 0.138 Train Accuracy: 91.38% Test Accuracy: 89.33% Time: 20.55s
# EPOCH: 129 Train Loss: 0.103 Test Loss: 0.138 Train Accuracy: 91.14% Test Accuracy: 89.32% Time: 20.49s
# EPOCH: 130 Train Loss: 0.102 Test Loss: 0.139 Train Accuracy: 91.21% Test Accuracy: 89.29% Time: 20.29s
# EPOCH: 131 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.26% Test Accuracy: 89.30% Time: 19.89s
# EPOCH: 132 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.31% Test Accuracy: 89.28% Time: 20.16s
# EPOCH: 133 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.34% Test Accuracy: 89.39% Time: 20.47s
# EPOCH: 134 Train Loss: 0.100 Test Loss: 0.138 Train Accuracy: 91.44% Test Accuracy: 89.32% Time: 20.09s
# EPOCH: 135 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.30% Test Accuracy: 89.33% Time: 20.33s
# EPOCH: 136 Train Loss: 0.101 Test Loss: 0.138 Train Accuracy: 91.13% Test Accuracy: 89.40% Time: 20.40s
# EPOCH: 137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 29
#      27     # Compute training statistics
#      28     _, predicted = torch.max(outputs, 1)
# ---> 29     correct += (predicted == labels).sum().item()
#      30     running_loss += loss.item()
#      32 avg_loss = running_loss / len(train_set)  # Average training loss for the epoch
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plotting Training Statistics
#
# Loss is a function of the difference of the network output and the target values. We are minimizing the loss function during training so it should decrease over time. Accuracy is the classification accuracy for the test data.

# %%
plots=[(loss_hist,loss_hist_test),(acc_hist,acc_hist_test)]
plt_labels=[("Training Loss","Test Loss"),("Training Accuracy","Test Accuracy")]
plt_titles=["Loss","Accuracy"]
plt.figure(figsize=(20,7))
for i in range(0,2):
    ax=plt.subplot(1,2,i+1)
    ax.plot(plots[i][0],label=plt_labels[i][0])
    ax.plot(plots[i][1],label=plt_labels[i][1])
    ax.set_title(plt_titles[i])
    ax.legend()

# %% [markdown]
# ## Save the trained model

# %%
# from google.colab import files
# torch.save(model.state_dict(), 'checkpoint.pth')
# # download checkpoint file
# files.download('checkpoint.pth')
# model.load_state_dict(torch.load('checkpoint.pth'))

# %% [markdown]
# # Test the Trained Network
# Finally, we test our best model on previously unseen test data and evaluate it's performance. Testing on unseen data is a good way to check that our model generalizes well. It may also be useful to be granular in this analysis and take a look at how this model performs on each class as well as looking at its overall loss and accuracy.

# %%
# Selecting the best model
best_acc = max(acc_hist_test)
best_epoch = acc_hist_test.index(best_acc)+1

print("Best accuracy on test set: {:.2f}%".format(best_acc*100))
print("Best epoch: {}".format(best_epoch))

# Load the best model
with open(f"Models/lenet5_model_{best_epoch}.pth","rb") as f:
    model=pickle.load(f)
# Out:
# Best accuracy on test set: 89.27%
# Best epoch: 97

# %% [markdown]
# # Recalculate Test Set Accuracy

# %%
pred_vec = []
label_vec = []
correct = 0
test_loss = 0.0
avg_test_loss = 0.0

model.to(device)
model.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        test_loss += loss.item()
        pred_vec.extend(predicted.cpu().numpy())  # Convert tensor to numpy array
        label_vec.extend(labels.cpu().numpy())  # Convert tensor to numpy array

    avg_test_loss = test_loss / len(test_set)

pred_vec = np.array(pred_vec)
label_vec = np.array(label_vec)

# %% [markdown]
# # Display the Test Set Accuracy

# %%
print(F"Test Loss: {avg_test_loss}")
print(F"Test Accuracy on the {len(test_set)} test images: {(100 * correct / len(test_set))}%")
# Out:
# Test Loss: 0.0013900840878486634
# Test Accuracy on the 10000 test images: 89.27%

# %% [markdown]
# # Display the Confusion Matrix

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(label_vec, pred_vec)
# Convert confusion matrix to pandas DataFrame
labels = np.unique(label_vec)
confusion_df = pd.DataFrame(confusion_mat, index=classes, columns=classes)
print("Confusion Matrix")
confusion_df
# Out:
# Confusion Matrix
#        plane  car  bird  cat  deer  dog  frog  horse  ship  truck
# plane    912    9    21   12     4    2     1      5    28      6
# car        4  961     2    2     0    0     0      1     6     24
# bird      31    0   854   36    35   16    18      4     4      2
# cat        9    1    38  786    29   85    23      8     9     12
# deer       4    2    28   19   891   17    19     18     1      1
# dog       10    1    20  102    17  825     5     18     1      1
# frog       5    2    27   25     7   13   916      2     1      2
# horse     10    1    12   18    21   23     0    911     0      4
# ship      28    9     5    5     0    0     1      1   941     10
# truck     15   40     1    3     0    0     0      1    10    930

# %% [markdown]
# # Compute the Accuracy, F1-Score, Precision, Recall, Support

# %%
# Create a report to show the f1-score, precision, recall
from sklearn.metrics import classification_report

report = pd.DataFrame.from_dict(classification_report(pred_vec,label_vec,output_dict=True)).T
report['Label']=[classes[int(x)] if x.isdigit() else " " for x in report.index]
report=report[['Label','f1-score','precision','recall','support']]
report
# Out:
#               Label  f1-score  precision    recall     support
# 0             plane  0.899408   0.912000  0.887160   1028.0000
# 1               car  0.948667   0.961000  0.936647   1026.0000
# 2              bird  0.850598   0.854000  0.847222   1008.0000
# 3               cat  0.782869   0.786000  0.779762   1008.0000
# 4              deer  0.889222   0.891000  0.887450   1004.0000
# 5               dog  0.832913   0.825000  0.840979    981.0000
# 6              frog  0.923853   0.916000  0.931841    983.0000
# 7             horse  0.925343   0.911000  0.940144    969.0000
# 8              ship  0.940530   0.941000  0.940060   1001.0000
# 9             truck  0.933735   0.930000  0.937500    992.0000
# accuracy             0.892700   0.892700  0.892700      0.8927
# macro avg            0.892714   0.892700  0.892877  10000.0000
# weighted avg         0.892686   0.892822  0.892700  10000.0000

# %% [markdown]
# In the context of classification, 'support' refers to the number of instances or samples in a dataset that belong to a specific class. It represents the frequency or count of occurrences of each class in the dataset.
#
# Support values help assess the reliability and generalizability of classification models, as they indicate the amount of data available for each class and the potential challenges associated with imbalanced datasets.

# %% [markdown]
# # Visualize Sample Test Results
# This cell displays test images and their labels in this format: predicted (ground-truth). The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
images, labels = next(iter(test_loader))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)

# Create a 4x4 grid for displaying the images
fig, axes = plt.subplots(4, 4, figsize=(8, 8))

# Iterate over the images and display them in the grid
for idx, ax in enumerate(axes.flat):
  # Normalize the image tensor to [0, 1] range
  image = images[idx].permute(1, 2, 0)
  image = (image - image.min()) / (image.max() - image.min())
  ax.imshow(image)  # Display the image
  ax.axis('off')  # Hide the axes
  ax.set_title("{}".format(classes[preds[idx]]),
                 color=("green" if preds[idx]==labels[idx] else "red"))  # Add title to the image
plt.show()

# %% [markdown]
# #Display 50 Predicted Images
# We iterate through 50 images and plot them with their corresponding label. We will color the label in blue if our model guessed correct and in red if it failed to predict that class.

# %%
# Define the loader for all test data
test_set_all = torchvision.datasets.CIFAR10(root='./data', train=False, download=False, transform=test_transform)
test_loader_all = torch.utils.data.DataLoader(test_set_all, batch_size=128, shuffle=False, num_workers=2)


# obtain one batch of test images
dataiter = iter(test_loader_all)
images, labels = next(iter(test_loader_all))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)


fig = plt.figure(figsize=(15, 7))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for idx in range(50):
    # Normalize the image tensor to [0, 1] range
    image = images[idx].permute(1, 2, 0)
    image = (image - image.min()) / (image.max() - image.min())
    ax = fig.add_subplot(5, 10, idx + 1, xticks=[], yticks=[])
    ax.imshow(image, interpolation='nearest')

    if preds[idx]==labels[idx]:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='green')
    else:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='red')

plt.show()

# %% [markdown]
# ## Visualize wrongly classified image for each class

# %%
# Visualize wrongly classified image for each class
pred_vec_all = []
correct = 0
test_loss = 0.0

model.to(device)
model.eval()
with torch.no_grad():
    for data in test_loader_all:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        test_loss=criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec_all.append(predicted)
    pred_vec_all = torch.cat(pred_vec_all)

pred_vec_all = pred_vec_all.cpu().numpy()
ground_truths = np.asarray(test_set_all.targets)
incorrect_mask = pred_vec_all != ground_truths
incorrect_images = [test_set_all.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results_all = [pred_vec_all[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results_all[i]], fontsize=10)
    axis.imshow(incorrect_images[i], cmap='gray')
    i += 1
