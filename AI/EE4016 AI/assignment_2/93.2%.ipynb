# %% [markdown]
# # PyTorch Convolutional Neural Network (CNN) With CIFAR-10 Color Image Dataset
#
# In this example, we demonstrate how to train a CNN model (aka ConvNet)  to classify images from the CIFAR-10 dataset. With the nature of CNN can handle spatial data of images and video, the RGB-color images  of CIFAR-10 can be directly use as input to the model.
#
# <img src='https://www.ee.cityu.edu.hk/~lmpo/ee5438/images/cnn_cifar10.png'>
#
#
# The CIFAR-10 dataset is a widely used collection of images that is commonly used to train machine learning and computer vision algorithms
#
# - It consists of 60,000 32x32 color images in 10 different classes
# - Each class contains 6,000 images, with 5,000 images for training and 1,000 images for testing
# - The 10 different classes in the CIFAR-10 dataset represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks
#
# The CIFAR-10 dataset can be split into training set, validation set, and test set in various ways. In this example, the way is to use 45,000 images for training, 5,000 images for validation, and 10,000 images for testing.
#
# <!-- <img src='https://corochann.com/wp-content/uploads/2021/09/cifar10_plot.png'> -->
#
#
# References:
#
# - https://github.com/nestorojeda/CIFAR-10-CNN

# %%
# Install the torchinfo package for showing the network architecture information
# !pip install torchinfo -qqq

# %%
# Import the necessary libraries for working with CIFART-10 dataset and PyTorch.
import torch
import torchvision
from torchvision import datasets,transforms
import torch.nn as nn
import torch.nn.functional as F
from torch import nn,optim,no_grad
from torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
from torchinfo import summary

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import pandas as pd
import numpy as np
import pickle
import sys
import time

# %%
# To configure the usage of a GPU (cuda) or MPS (Apple) if either of them is available
has_mps = torch.backends.mps.is_built()
device = "cuda" if torch.cuda.is_available() else "mps" if has_mps else "cpu"
print(f"Python versoin: {sys.version_info.major, sys.version_info.minor, sys.version_info.micro}")
print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")
# Out:
# Python versoin: (3, 11, 9)
# PyTorch version: 2.4.1+cu118
# Device: cuda

# %%
# Set seed for reproducibility
seed = 4016
torch.manual_seed(seed)

# %% [markdown]
# # Download CIFAR10 Dataset
#
# This code snippet helps us download the CIFAR-10 dataset, which is a popular dataset used for training and evaluating deep learning models. The dataset is divided into a training set and a test set.
#
# In deep learning, it's common to split the dataset into training, validation, and test sets. However, in this particular example, the validation set is not used. Instead, we only use the training set to train our model. The training set consists of 50,000 samples, and we use these samples to teach our model how to recognize and classify images.
#
# **During and after training, the model's performance is evaluated by the test set with 10,000 samples. The test set contains a separate set of samples that were not used to update the model's parameters during the training.** We use this test set to assess how well our trained model can generalize to new, unseen data.
#
# By creating DataLoaders, we can easily handle the downloading and loading of the training and test sets, making it convenient for us to train our deep learning model on the CIFAR-10 dataset.

# %%
# Define data transformations for the training and test sets
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    
    ])

test_transform = transforms.Compose([
     transforms.ToTensor(), # Convert images to tensors
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))]) # Normalize the image data

# Create the CIFAR10dataset for the training set with 50,000 images
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)

# Create the CIFAR10 dataset for the test set with 10,000 images (It is also used as validation set during the training)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

# Define the data loaders for the training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_set, batch_size=256, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=256, shuffle=False, num_workers=2)

# Define the classes for the CIFAR-10 dataset
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Visualize image for each class
#
# The first step in a classification task is to take a look at the data, make sure it is loaded in correctly, then make any initial observations about patterns in that data.

# %%
# Visualize training image for each class
sample_images = [train_set.data[np.asarray(train_set.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# ## Define the CNN Architecture
#
# The following code defines a class called CNN_Model which inherits from nn.Module. The network has 3 fully-connected layers:
#
# - In the first line, we use the "Conv2d" module to implement a convolutional neural network. The first parameter, 3, indicates that the input image is colored and in RGB format. If it were a grayscale image, we would use 1 instead.
#
# - The number 32 represents the initial output channels, and in the next Conv2d layer, we would use 32 as the input channels and 64 as the output channels.
#
# - The third parameter in the first line is the kernel size, which determines the size of the filters used. The last parameter is for padding, which helps maintain the spatial dimensions of the input.
#
# After each Conv2d layer, we apply an activation function, specifically the Rectified Linear Unit (ReLU). Following two Conv2d layers, we perform a max-pooling operation with a 2x2 size. The resulting values are then batch normalized to ensure stability and avoid internal covariate shift. These operations are repeated with additional layers to make the network deeper and reduce the size of the data. Finally, we flatten the layer to create a linear layer that maps the values to 10 outputs. The probability of each neuron in these 10 outputs determines the class to which a particular image belongs, with the highest probability indicating the predicted class.

# %%
class CNN(nn.Module):
  def __init__(self):
    super().__init__()
    # First block
    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
    self.bn1 = nn.BatchNorm2d(64)
    self.conv2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
    self.bn2 = nn.BatchNorm2d(64)
    self.pool = nn.MaxPool2d(2, 2)
    self.dropout1 = nn.Dropout(0.2)
    
    # Add self-attention after first block
    self.attention1 = SelfAttention(64)
    
    # Second block
    self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
    self.bn3 = nn.BatchNorm2d(128)
    self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
    self.bn4 = nn.BatchNorm2d(128)
    self.dropout2 = nn.Dropout(0.3)
    
    # Add self-attention after second block
    self.attention2 = SelfAttention(128)
    
    # Third block
    self.conv5 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
    self.bn5 = nn.BatchNorm2d(256)
    self.conv6 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
    self.bn6 = nn.BatchNorm2d(256)
    self.dropout3 = nn.Dropout(0.4)
    
    # Add self-attention after third block
    self.attention3 = SelfAttention(256)
    
    # Fully connected layers
    self.fc1 = nn.Linear(256 * 4 * 4, 1024)
    self.bn7 = nn.BatchNorm1d(1024)
    self.dropout4 = nn.Dropout(0.5)
    self.fc2 = nn.Linear(1024, 10)

  def forward(self, x):
    # First block
    x = F.relu(self.bn1(self.conv1(x)))
    x = F.relu(self.bn2(self.conv2(x)))
    x = self.pool(x)
    x = self.dropout1(x)
    x = self.attention1(x)  # Add attention
    
    # Second block
    x = F.relu(self.bn3(self.conv3(x)))
    x = F.relu(self.bn4(self.conv4(x)))
    x = self.pool(x)
    x = self.dropout2(x)
    x = self.attention2(x)  # Add attention
    
    # Third block
    x = F.relu(self.bn5(self.conv5(x)))
    x = F.relu(self.bn6(self.conv6(x)))
    x = self.pool(x)
    x = self.dropout3(x)
    x = self.attention3(x)  # Add attention
    
    # Fully connected layers
    x = x.view(-1, 256 * 4 * 4)
    x = F.relu(self.bn7(self.fc1(x)))
    x = self.dropout4(x)
    x = self.fc2(x)
    
    return x

# Self-attention module
class SelfAttention(nn.Module):
  def __init__(self, in_channels):
      super().__init__()
      # Reduce channel dimensions for efficiency
      self.query = nn.Conv2d(in_channels, in_channels//8, 1)
      self.key = nn.Conv2d(in_channels, in_channels//8, 1)
      self.value = nn.Conv2d(in_channels, in_channels, 1)
      self.gamma = nn.Parameter(torch.zeros(1))  # Learnable scaling parameter

  def forward(self, x):
      batch_size, channels, height, width = x.size()
      
      # Create query, key, value
      query = self.query(x).view(batch_size, -1, height*width)
      key = self.key(x).view(batch_size, -1, height*width)
      value = self.value(x).view(batch_size, -1, height*width)
      
      # Calculate attention scores
      attention = torch.bmm(query.transpose(1,2), key)
      attention = F.softmax(attention, dim=2)
      
      # Apply attention to values
      out = torch.bmm(value, attention.transpose(1,2))
      out = out.view(batch_size, channels, height, width)
      
      # Apply learned scaling
      out = self.gamma * out + x
      
      return out

# %%
model = CNN()

# %%
summary(model=model, input_size=(1, 3, 32, 32), col_width=15,
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        row_settings=['var_names'], verbose=0)
# Out:
# ====================================================================================================
# Layer (type (var_name))                  Input Shape     Output Shape    Param #         Trainable
# ====================================================================================================
# CNN (CNN)                                [1, 3, 32, 32]  [1, 10]         --              True
# ├─Conv2d (conv1)                         [1, 3, 32, 32]  [1, 64, 32, 32] 1,792           True
# ├─BatchNorm2d (bn1)                      [1, 64, 32, 32] [1, 64, 32, 32] 128             True
# ├─Conv2d (conv2)                         [1, 64, 32, 32] [1, 64, 32, 32] 36,928          True
# ├─BatchNorm2d (bn2)                      [1, 64, 32, 32] [1, 64, 32, 32] 128             True
# ├─MaxPool2d (pool)                       [1, 64, 32, 32] [1, 64, 16, 16] --              --
# ├─Dropout (dropout1)                     [1, 64, 16, 16] [1, 64, 16, 16] --              --
# ├─SelfAttention (attention1)             [1, 64, 16, 16] [1, 64, 16, 16] 1               True
# │    └─Conv2d (query)                    [1, 64, 16, 16] [1, 8, 16, 16]  520             True
# │    └─Conv2d (key)                      [1, 64, 16, 16] [1, 8, 16, 16]  520             True
# │    └─Conv2d (value)                    [1, 64, 16, 16] [1, 64, 16, 16] 4,160           True
# ├─Conv2d (conv3)                         [1, 64, 16, 16] [1, 128, 16, 16] 73,856          True
# ├─BatchNorm2d (bn3)                      [1, 128, 16, 16] [1, 128, 16, 16] 256             True
# ├─Conv2d (conv4)                         [1, 128, 16, 16] [1, 128, 16, 16] 147,584         True
# ├─BatchNorm2d (bn4)                      [1, 128, 16, 16] [1, 128, 16, 16] 256             True
# ├─MaxPool2d (pool)                       [1, 128, 16, 16] [1, 128, 8, 8]  --              --
# ├─Dropout (dropout2)                     [1, 128, 8, 8]  [1, 128, 8, 8]  --              --
# ├─SelfAttention (attention2)             [1, 128, 8, 8]  [1, 128, 8, 8]  1               True
# │    └─Conv2d (query)                    [1, 128, 8, 8]  [1, 16, 8, 8]   2,064           True
# │    └─Conv2d (key)                      [1, 128, 8, 8]  [1, 16, 8, 8]   2,064           True
# │    └─Conv2d (value)                    [1, 128, 8, 8]  [1, 128, 8, 8]  16,512          True
# ├─Conv2d (conv5)                         [1, 128, 8, 8]  [1, 256, 8, 8]  295,168         True
# ├─BatchNorm2d (bn5)                      [1, 256, 8, 8]  [1, 256, 8, 8]  512             True
# ├─Conv2d (conv6)                         [1, 256, 8, 8]  [1, 256, 8, 8]  590,080         True
# ├─BatchNorm2d (bn6)                      [1, 256, 8, 8]  [1, 256, 8, 8]  512             True
# ├─MaxPool2d (pool)                       [1, 256, 8, 8]  [1, 256, 4, 4]  --              --
# ├─Dropout (dropout3)                     [1, 256, 4, 4]  [1, 256, 4, 4]  --              --
# ├─SelfAttention (attention3)             [1, 256, 4, 4]  [1, 256, 4, 4]  1               True
# │    └─Conv2d (query)                    [1, 256, 4, 4]  [1, 32, 4, 4]   8,224           True
# │    └─Conv2d (key)                      [1, 256, 4, 4]  [1, 32, 4, 4]   8,224           True
# │    └─Conv2d (value)                    [1, 256, 4, 4]  [1, 256, 4, 4]  65,792          True
# ├─Linear (fc1)                           [1, 4096]       [1, 1024]       4,195,328       True
# ├─BatchNorm1d (bn7)                      [1, 1024]       [1, 1024]       2,048           True
# ├─Dropout (dropout4)                     [1, 1024]       [1, 1024]       --              --
# ├─Linear (fc2)                           [1, 1024]       [1, 10]         10,250          True
# ====================================================================================================
# Total params: 5,462,909
# Trainable params: 5,462,909
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 161.17
# ====================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.97
# Params size (MB): 21.85
# Estimated Total Size (MB): 25.84
# ====================================================================================================

# %% [markdown]
# ## Training the Network
#
# The steps for training/learning from a batch of data are described in the comments below:
#
# Clear the gradients of all optimized variables
# Forward pass: compute predicted outputs by passing inputs to the model
# Calculate the loss
# Backward pass: compute gradient of the loss with respect to model parameters
# Perform a single optimization step (parameter update)
# Update average training loss
# The following loop trains for 50 epochs; take a look at how the values for the training loss decrease over time. We want it to decrease while also avoiding overfitting the training data.

# %%
# Create a Models folder to store the checkpoints
# !mkdir Models
# Out:
# �l�ؿ����ɮ� Models �w�g�s�b�C

# %% [markdown]
# ## Specify Loss Function and Optimizer
# It's recommended that you use cross-entropy loss for classification. If you look at the documentation (linked above), you can see that PyTorch's cross entropy function applies a softmax funtion to the output layer and then calculates the log loss.

# %%
# Specify Loss/Cost function
criterion = nn.CrossEntropyLoss()

# Specify optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
#optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum = 0.2)
#optimizer = optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
# optimizer = optim.SGD(model.parameters(), lr=0.01)

# Specify Learning Rate Scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True, min_lr=0)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=5, verbose=True)
# Out:
# g:\python\ee4016 ai\assignment_1\venv\Lib\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
EPOCHS = 120

loss_hist, acc_hist = [], []  # Lists to store training loss and accuracy
loss_hist_test, acc_hist_test = [], []  # Lists to store validation loss and accuracy

model.to(device)  # Move the model to the specified device (e.g., GPU)

print("Training was started.\n")

for epoch in range(1, EPOCHS + 1):
    time_ckpt = time.time()
    print("EPOCH:", epoch, end=" ")
    running_loss = 0.0
    correct = 0

    # Training loop
    for data in train_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)

        optimizer.zero_grad()  # Clear the gradients
        outputs = model(batch)  # Forward pass
        loss = criterion(outputs, labels)  # Compute the loss
        loss.backward()  # Backward pass (compute gradients)
        optimizer.step()  # Update the model's parameters

        # Compute training statistics
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

    avg_loss = running_loss / len(train_set)  # Average training loss for the epoch
    avg_acc = correct / len(train_set)  # Average training accuracy for the epoch
    loss_hist.append(avg_loss)
    acc_hist.append(avg_acc)

    # Validation statistics
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        loss_test = 0.0
        correct_test = 0

        # Validation loop
        for data in test_loader:
            batch, labels = data
            batch, labels = batch.to(device), labels.to(device)
            outputs = model(batch)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            correct_test += (predicted == labels).sum().item()
            loss_test += loss.item()

        avg_loss_test = loss_test / len(test_set)  # Average validation loss for the epoch
        avg_acc_test = correct_test / len(test_set)  # Average validation accuracy for the epoch
        loss_hist_test.append(avg_loss_test)
        acc_hist_test.append(avg_acc_test)


    model.train()  # Set the model back to training mode

    scheduler.step(avg_loss_test) # Check the scheduler for updating the learning rate

    # Save the model at the end of each epoch
    with open("Models/lenet5_model_{}.pth".format(epoch), "wb") as f:
        model.eval()
        pickle.dump(model, f)
        model.train()

    print("Train Loss: {:.3f}".format(avg_loss * 100), end=" ")
    print("Test Loss: {:.3f}".format(avg_loss_test * 100), end=" ")
    print("Train Accuracy: {:.2f}%".format(avg_acc * 100), end=" ")
    print("Test Accuracy: {:.2f}%".format(avg_acc_test * 100), end=" ")
    print("Time: {:.2f}s".format(time.time() - time_ckpt), end=" \n")
# Out:
# Training was started.
#
# EPOCH: 1 Train Loss: 0.614 Test Loss: 0.470 Train Accuracy: 42.92% Test Accuracy: 60.21% Time: 20.42s
# EPOCH: 2 Train Loss: 0.434 Test Loss: 0.364 Train Accuracy: 60.26% Test Accuracy: 67.31% Time: 19.84s
# EPOCH: 3 Train Loss: 0.365 Test Loss: 0.302 Train Accuracy: 67.00% Test Accuracy: 73.53% Time: 23.57s
# EPOCH: 4 Train Loss: 0.332 Test Loss: 0.285 Train Accuracy: 70.15% Test Accuracy: 76.11% Time: 26.63s
# EPOCH: 5 Train Loss: 0.303 Test Loss: 0.261 Train Accuracy: 72.74% Test Accuracy: 77.64% Time: 27.85s
# EPOCH: 6 Train Loss: 0.285 Test Loss: 0.240 Train Accuracy: 74.61% Test Accuracy: 78.73% Time: 28.35s
# EPOCH: 7 Train Loss: 0.269 Test Loss: 0.237 Train Accuracy: 76.02% Test Accuracy: 79.35% Time: 26.74s
# EPOCH: 8 Train Loss: 0.257 Test Loss: 0.234 Train Accuracy: 77.18% Test Accuracy: 79.76% Time: 26.67s
# EPOCH: 9 Train Loss: 0.246 Test Loss: 0.211 Train Accuracy: 77.95% Test Accuracy: 82.32% Time: 26.98s
# EPOCH: 10 Train Loss: 0.237 Test Loss: 0.196 Train Accuracy: 78.83% Test Accuracy: 82.99% Time: 26.98s
# EPOCH: 11 Train Loss: 0.229 Test Loss: 0.201 Train Accuracy: 79.80% Test Accuracy: 82.71% Time: 26.97s
# EPOCH: 12 Train Loss: 0.219 Test Loss: 0.189 Train Accuracy: 80.48% Test Accuracy: 83.83% Time: 27.10s
# EPOCH: 13 Train Loss: 0.214 Test Loss: 0.170 Train Accuracy: 81.32% Test Accuracy: 85.54% Time: 27.34s
# EPOCH: 14 Train Loss: 0.207 Test Loss: 0.189 Train Accuracy: 81.74% Test Accuracy: 83.66% Time: 27.13s
# EPOCH: 15 Train Loss: 0.203 Test Loss: 0.201 Train Accuracy: 81.93% Test Accuracy: 83.44% Time: 27.69s
# EPOCH: 16 Train Loss: 0.196 Test Loss: 0.196 Train Accuracy: 82.71% Test Accuracy: 83.76% Time: 28.07s
# EPOCH: 17 Train Loss: 0.193 Test Loss: 0.159 Train Accuracy: 82.86% Test Accuracy: 86.23% Time: 27.72s
# EPOCH: 18 Train Loss: 0.188 Test Loss: 0.176 Train Accuracy: 83.30% Test Accuracy: 85.05% Time: 27.91s
# EPOCH: 19 Train Loss: 0.182 Test Loss: 0.173 Train Accuracy: 84.02% Test Accuracy: 85.98% Time: 27.59s
# EPOCH: 20 Train Loss: 0.181 Test Loss: 0.159 Train Accuracy: 83.93% Test Accuracy: 86.74% Time: 27.65s
# EPOCH: 21 Train Loss: 0.175 Test Loss: 0.152 Train Accuracy: 84.50% Test Accuracy: 86.83% Time: 27.61s
# EPOCH: 22 Train Loss: 0.173 Test Loss: 0.165 Train Accuracy: 84.66% Test Accuracy: 85.95% Time: 27.49s
# EPOCH: 23 Train Loss: 0.170 Test Loss: 0.147 Train Accuracy: 84.92% Test Accuracy: 87.28% Time: 27.16s
# EPOCH: 24 Train Loss: 0.166 Test Loss: 0.147 Train Accuracy: 85.39% Test Accuracy: 87.33% Time: 27.30s
# EPOCH: 25 Train Loss: 0.163 Test Loss: 0.143 Train Accuracy: 85.50% Test Accuracy: 87.63% Time: 24.38s
# EPOCH: 26 Train Loss: 0.162 Test Loss: 0.156 Train Accuracy: 85.68% Test Accuracy: 86.81% Time: 20.74s
# EPOCH: 27 Train Loss: 0.159 Test Loss: 0.151 Train Accuracy: 85.84% Test Accuracy: 87.05% Time: 20.62s
# EPOCH: 28 Train Loss: 0.157 Test Loss: 0.136 Train Accuracy: 86.27% Test Accuracy: 88.36% Time: 20.58s
# EPOCH: 29 Train Loss: 0.154 Test Loss: 0.144 Train Accuracy: 86.37% Test Accuracy: 87.69% Time: 20.39s
# EPOCH: 30 Train Loss: 0.152 Test Loss: 0.147 Train Accuracy: 86.47% Test Accuracy: 88.00% Time: 20.40s
# EPOCH: 31 Train Loss: 0.150 Test Loss: 0.140 Train Accuracy: 86.76% Test Accuracy: 88.50% Time: 20.71s
# EPOCH: 32 Train Loss: 0.146 Test Loss: 0.147 Train Accuracy: 87.02% Test Accuracy: 87.85% Time: 20.88s
# EPOCH: 33 Train Loss: 0.147 Test Loss: 0.136 Train Accuracy: 87.05% Test Accuracy: 88.00% Time: 20.61s
# EPOCH: 34 Train Loss: 0.144 Test Loss: 0.130 Train Accuracy: 87.27% Test Accuracy: 89.00% Time: 20.55s
# EPOCH: 35 Train Loss: 0.144 Test Loss: 0.123 Train Accuracy: 87.31% Test Accuracy: 89.19% Time: 20.65s
# EPOCH: 36 Train Loss: 0.140 Test Loss: 0.137 Train Accuracy: 87.65% Test Accuracy: 88.31% Time: 21.67s
# EPOCH: 37 Train Loss: 0.139 Test Loss: 0.129 Train Accuracy: 87.72% Test Accuracy: 89.16% Time: 21.09s
# EPOCH: 38 Train Loss: 0.138 Test Loss: 0.158 Train Accuracy: 87.77% Test Accuracy: 86.91% Time: 21.24s
# EPOCH: 39 Train Loss: 0.136 Test Loss: 0.151 Train Accuracy: 88.08% Test Accuracy: 87.73% Time: 20.72s
# EPOCH: 40 Train Loss: 0.135 Test Loss: 0.133 Train Accuracy: 88.01% Test Accuracy: 88.95% Time: 20.86s
# EPOCH: 41 Train Loss: 0.133 Test Loss: 0.121 Train Accuracy: 88.30% Test Accuracy: 89.69% Time: 20.71s
# EPOCH: 42 Train Loss: 0.133 Test Loss: 0.153 Train Accuracy: 88.18% Test Accuracy: 87.83% Time: 21.63s
# EPOCH: 43 Train Loss: 0.132 Test Loss: 0.129 Train Accuracy: 88.46% Test Accuracy: 88.90% Time: 21.47s
# EPOCH: 44 Train Loss: 0.128 Test Loss: 0.139 Train Accuracy: 88.73% Test Accuracy: 88.69% Time: 22.04s
# EPOCH: 45 Train Loss: 0.129 Test Loss: 0.116 Train Accuracy: 88.56% Test Accuracy: 90.07% Time: 21.53s
# EPOCH: 46 Train Loss: 0.130 Test Loss: 0.126 Train Accuracy: 88.47% Test Accuracy: 89.49% Time: 20.94s
# EPOCH: 47 Train Loss: 0.126 Test Loss: 0.150 Train Accuracy: 88.90% Test Accuracy: 87.38% Time: 20.98s
# EPOCH: 48 Train Loss: 0.125 Test Loss: 0.119 Train Accuracy: 89.00% Test Accuracy: 89.93% Time: 20.77s
# EPOCH: 49 Train Loss: 0.125 Test Loss: 0.150 Train Accuracy: 88.95% Test Accuracy: 87.66% Time: 20.98s
# EPOCH: 50 Train Loss: 0.125 Test Loss: 0.124 Train Accuracy: 88.97% Test Accuracy: 89.77% Time: 21.07s
# EPOCH: 51 Train Loss: 0.125 Test Loss: 0.137 Train Accuracy: 88.88% Test Accuracy: 88.79% Time: 21.67s
# EPOCH: 52 Train Loss: 0.121 Test Loss: 0.120 Train Accuracy: 89.24% Test Accuracy: 89.95% Time: 21.98s
# EPOCH: 53 Train Loss: 0.122 Test Loss: 0.142 Train Accuracy: 89.19% Test Accuracy: 88.33% Time: 22.24s
# EPOCH: 54 Train Loss: 0.120 Test Loss: 0.125 Train Accuracy: 89.36% Test Accuracy: 90.17% Time: 22.39s
# EPOCH: 55 Train Loss: 0.121 Test Loss: 0.112 Train Accuracy: 89.26% Test Accuracy: 90.82% Time: 21.45s
# EPOCH: 56 Train Loss: 0.120 Test Loss: 0.124 Train Accuracy: 89.48% Test Accuracy: 89.65% Time: 21.35s
# EPOCH: 57 Train Loss: 0.115 Test Loss: 0.124 Train Accuracy: 89.82% Test Accuracy: 89.65% Time: 20.54s
# EPOCH: 58 Train Loss: 0.117 Test Loss: 0.119 Train Accuracy: 89.62% Test Accuracy: 90.19% Time: 20.47s
# EPOCH: 59 Train Loss: 0.119 Test Loss: 0.139 Train Accuracy: 89.58% Test Accuracy: 88.83% Time: 20.37s
# EPOCH: 60 Train Loss: 0.115 Test Loss: 0.133 Train Accuracy: 89.85% Test Accuracy: 89.66% Time: 20.62s
# EPOCH: 61 Train Loss: 0.114 Test Loss: 0.130 Train Accuracy: 89.88% Test Accuracy: 89.67% Time: 20.38s
# EPOCH: 62 Train Loss: 0.115 Test Loss: 0.114 Train Accuracy: 89.74% Test Accuracy: 90.76% Time: 20.75s
# EPOCH: 63 Train Loss: 0.112 Test Loss: 0.127 Train Accuracy: 90.04% Test Accuracy: 89.61% Time: 20.41s
# EPOCH: 64 Train Loss: 0.113 Test Loss: 0.124 Train Accuracy: 90.10% Test Accuracy: 89.96% Time: 20.24s
# EPOCH: 65 Train Loss: 0.113 Test Loss: 0.110 Train Accuracy: 90.02% Test Accuracy: 90.93% Time: 20.38s
# EPOCH: 66 Train Loss: 0.111 Test Loss: 0.108 Train Accuracy: 90.19% Test Accuracy: 90.98% Time: 20.41s
# EPOCH: 67 Train Loss: 0.110 Test Loss: 0.118 Train Accuracy: 90.29% Test Accuracy: 90.66% Time: 20.35s
# EPOCH: 68 Train Loss: 0.110 Test Loss: 0.109 Train Accuracy: 90.24% Test Accuracy: 91.10% Time: 20.38s
# EPOCH: 69 Train Loss: 0.110 Test Loss: 0.106 Train Accuracy: 90.32% Test Accuracy: 91.38% Time: 20.65s
# EPOCH: 70 Train Loss: 0.109 Test Loss: 0.128 Train Accuracy: 90.40% Test Accuracy: 89.74% Time: 20.79s
# EPOCH: 71 Train Loss: 0.111 Test Loss: 0.125 Train Accuracy: 90.24% Test Accuracy: 89.78% Time: 21.34s
# EPOCH: 72 Train Loss: 0.110 Test Loss: 0.116 Train Accuracy: 90.42% Test Accuracy: 90.20% Time: 21.23s
# EPOCH: 73 Train Loss: 0.109 Test Loss: 0.115 Train Accuracy: 90.26% Test Accuracy: 90.54% Time: 20.19s
# EPOCH: 74 Train Loss: 0.106 Test Loss: 0.115 Train Accuracy: 90.57% Test Accuracy: 90.61% Time: 21.29s
# EPOCH: 75 Train Loss: 0.107 Test Loss: 0.118 Train Accuracy: 90.46% Test Accuracy: 90.45% Time: 21.09s
# EPOCH: 76 Train Loss: 0.108 Test Loss: 0.116 Train Accuracy: 90.45% Test Accuracy: 90.52% Time: 20.23s
# EPOCH: 77 Train Loss: 0.106 Test Loss: 0.109 Train Accuracy: 90.48% Test Accuracy: 90.85% Time: 20.93s
# EPOCH: 78 Train Loss: 0.104 Test Loss: 0.130 Train Accuracy: 90.77% Test Accuracy: 89.41% Time: 20.37s
# EPOCH: 79 Train Loss: 0.105 Test Loss: 0.116 Train Accuracy: 90.66% Test Accuracy: 90.45% Time: 20.03s
# EPOCH: 80 Train Loss: 0.107 Test Loss: 0.111 Train Accuracy: 90.54% Test Accuracy: 91.25% Time: 20.46s
# EPOCH: 81 Train Loss: 0.086 Test Loss: 0.097 Train Accuracy: 92.40% Test Accuracy: 91.97% Time: 20.36s
# EPOCH: 82 Train Loss: 0.078 Test Loss: 0.096 Train Accuracy: 93.07% Test Accuracy: 92.25% Time: 21.22s
# EPOCH: 83 Train Loss: 0.076 Test Loss: 0.095 Train Accuracy: 93.35% Test Accuracy: 92.29% Time: 21.28s
# EPOCH: 84 Train Loss: 0.073 Test Loss: 0.092 Train Accuracy: 93.47% Test Accuracy: 92.54% Time: 20.62s
# EPOCH: 85 Train Loss: 0.070 Test Loss: 0.093 Train Accuracy: 93.67% Test Accuracy: 92.54% Time: 20.45s
# EPOCH: 86 Train Loss: 0.068 Test Loss: 0.093 Train Accuracy: 93.88% Test Accuracy: 92.47% Time: 20.79s
# EPOCH: 87 Train Loss: 0.067 Test Loss: 0.092 Train Accuracy: 94.06% Test Accuracy: 92.39% Time: 20.57s
# EPOCH: 88 Train Loss: 0.066 Test Loss: 0.093 Train Accuracy: 94.13% Test Accuracy: 92.53% Time: 19.99s
# EPOCH: 89 Train Loss: 0.065 Test Loss: 0.094 Train Accuracy: 94.18% Test Accuracy: 92.59% Time: 20.13s
# EPOCH: 90 Train Loss: 0.064 Test Loss: 0.093 Train Accuracy: 94.25% Test Accuracy: 92.57% Time: 19.85s
# EPOCH: 91 Train Loss: 0.064 Test Loss: 0.094 Train Accuracy: 94.19% Test Accuracy: 92.49% Time: 20.02s
# EPOCH: 92 Train Loss: 0.062 Test Loss: 0.091 Train Accuracy: 94.45% Test Accuracy: 92.88% Time: 19.97s
# EPOCH: 93 Train Loss: 0.061 Test Loss: 0.091 Train Accuracy: 94.56% Test Accuracy: 92.82% Time: 20.00s
# EPOCH: 94 Train Loss: 0.060 Test Loss: 0.092 Train Accuracy: 94.63% Test Accuracy: 92.73% Time: 19.96s
# EPOCH: 95 Train Loss: 0.061 Test Loss: 0.093 Train Accuracy: 94.61% Test Accuracy: 92.57% Time: 19.98s
# EPOCH: 96 Train Loss: 0.059 Test Loss: 0.091 Train Accuracy: 94.74% Test Accuracy: 93.02% Time: 19.89s
# EPOCH: 97 Train Loss: 0.059 Test Loss: 0.093 Train Accuracy: 94.64% Test Accuracy: 92.74% Time: 20.33s
# EPOCH: 98 Train Loss: 0.057 Test Loss: 0.093 Train Accuracy: 95.02% Test Accuracy: 92.89% Time: 19.84s
# EPOCH: 99 Train Loss: 0.057 Test Loss: 0.094 Train Accuracy: 94.96% Test Accuracy: 92.62% Time: 19.96s
# EPOCH: 100 Train Loss: 0.057 Test Loss: 0.093 Train Accuracy: 94.91% Test Accuracy: 92.91% Time: 19.99s
# EPOCH: 101 Train Loss: 0.055 Test Loss: 0.094 Train Accuracy: 95.18% Test Accuracy: 92.62% Time: 20.39s
# EPOCH: 102 Train Loss: 0.054 Test Loss: 0.093 Train Accuracy: 95.19% Test Accuracy: 93.00% Time: 20.39s
# EPOCH: 103 Train Loss: 0.054 Test Loss: 0.095 Train Accuracy: 95.14% Test Accuracy: 92.68% Time: 20.25s
# EPOCH: 104 Train Loss: 0.054 Test Loss: 0.094 Train Accuracy: 95.10% Test Accuracy: 92.73% Time: 20.18s
# EPOCH: 105 Train Loss: 0.054 Test Loss: 0.093 Train Accuracy: 95.03% Test Accuracy: 92.85% Time: 20.57s
# EPOCH: 106 Train Loss: 0.053 Test Loss: 0.094 Train Accuracy: 95.28% Test Accuracy: 92.82% Time: 20.38s
# EPOCH: 107 Train Loss: 0.053 Test Loss: 0.094 Train Accuracy: 95.21% Test Accuracy: 92.82% Time: 20.46s
# EPOCH: 108 Train Loss: 0.050 Test Loss: 0.093 Train Accuracy: 95.47% Test Accuracy: 92.93% Time: 20.54s
# EPOCH: 109 Train Loss: 0.051 Test Loss: 0.093 Train Accuracy: 95.38% Test Accuracy: 92.83% Time: 20.86s
# EPOCH: 110 Train Loss: 0.050 Test Loss: 0.092 Train Accuracy: 95.43% Test Accuracy: 92.98% Time: 21.65s
# EPOCH: 111 Train Loss: 0.051 Test Loss: 0.093 Train Accuracy: 95.51% Test Accuracy: 92.90% Time: 22.20s
# EPOCH: 112 Train Loss: 0.050 Test Loss: 0.093 Train Accuracy: 95.41% Test Accuracy: 92.79% Time: 20.66s
# EPOCH: 113 Train Loss: 0.050 Test Loss: 0.093 Train Accuracy: 95.54% Test Accuracy: 92.88% Time: 20.72s
# EPOCH: 114 Train Loss: 0.051 Test Loss: 0.093 Train Accuracy: 95.49% Test Accuracy: 92.91% Time: 21.55s
# EPOCH: 115 Train Loss: 0.049 Test Loss: 0.093 Train Accuracy: 95.63% Test Accuracy: 92.74% Time: 21.13s
# EPOCH: 116 Train Loss: 0.050 Test Loss: 0.093 Train Accuracy: 95.56% Test Accuracy: 92.98% Time: 20.61s
# EPOCH: 117 Train Loss: 0.048 Test Loss: 0.093 Train Accuracy: 95.82% Test Accuracy: 92.82% Time: 20.19s
# EPOCH: 118 Train Loss: 0.049 Test Loss: 0.093 Train Accuracy: 95.48% Test Accuracy: 92.93% Time: 20.34s
# EPOCH: 119 Train Loss: 0.049 Test Loss: 0.093 Train Accuracy: 95.68% Test Accuracy: 92.96% Time: 20.16s
# EPOCH: 120 Train Loss: 0.049 Test Loss: 0.093 Train Accuracy: 95.68% Test Accuracy: 92.91% Time: 20.05s

# %% [markdown]
# ## Plotting Training Statistics
#
# Loss is a function of the difference of the network output and the target values. We are minimizing the loss function during training so it should decrease over time. Accuracy is the classification accuracy for the test data.

# %%
plots=[(loss_hist,loss_hist_test),(acc_hist,acc_hist_test)]
plt_labels=[("Training Loss","Test Loss"),("Training Accuracy","Test Accuracy")]
plt_titles=["Loss","Accuracy"]
plt.figure(figsize=(20,7))
for i in range(0,2):
    ax=plt.subplot(1,2,i+1)
    ax.plot(plots[i][0],label=plt_labels[i][0])
    ax.plot(plots[i][1],label=plt_labels[i][1])
    ax.set_title(plt_titles[i])
    ax.legend()

# %% [markdown]
# ## Save the trained model

# %%
# from google.colab import files
# torch.save(model.state_dict(), 'checkpoint.pth')
# # download checkpoint file
# files.download('checkpoint.pth')
# model.load_state_dict(torch.load('checkpoint.pth'))

# %% [markdown]
# # Test the Trained Network
# Finally, we test our best model on previously unseen test data and evaluate it's performance. Testing on unseen data is a good way to check that our model generalizes well. It may also be useful to be granular in this analysis and take a look at how this model performs on each class as well as looking at its overall loss and accuracy.

# %%
# Selecting the best model
best_acc = max(acc_hist_test)
best_epoch = acc_hist_test.index(best_acc)+1

print("Best accuracy on test set: {:.2f}%".format(best_acc*100))
print("Best epoch: {}".format(best_epoch))

# Load the best model
with open(f"Models/lenet5_model_{best_epoch}.pth","rb") as f:
    model=pickle.load(f)
# Out:
# Best accuracy on test set: 93.02%
# Best epoch: 96

# %% [markdown]
# # Recalculate Test Set Accuracy

# %%
pred_vec = []
label_vec = []
correct = 0
test_loss = 0.0
avg_test_loss = 0.0

model.to(device)
model.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        test_loss += loss.item()
        pred_vec.extend(predicted.cpu().numpy())  # Convert tensor to numpy array
        label_vec.extend(labels.cpu().numpy())  # Convert tensor to numpy array

    avg_test_loss = test_loss / len(test_set)

pred_vec = np.array(pred_vec)
label_vec = np.array(label_vec)

# %% [markdown]
# # Display the Test Set Accuracy

# %%
print(F"Test Loss: {avg_test_loss}")
print(F"Test Accuracy on the {len(test_set)} test images: {(100 * correct / len(test_set))}%")
# Out:
# Test Loss: 0.0009080763846635819
# Test Accuracy on the 10000 test images: 93.02%

# %% [markdown]
# # Display the Confusion Matrix

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(label_vec, pred_vec)
# Convert confusion matrix to pandas DataFrame
labels = np.unique(label_vec)
confusion_df = pd.DataFrame(confusion_mat, index=classes, columns=classes)
print("Confusion Matrix")
confusion_df
# Out:
# Confusion Matrix
#        plane  car  bird  cat  deer  dog  frog  horse  ship  truck
# plane    941    5    13    4     4    0     1      1    23      8
# car        4  963     0    0     1    0     0      0     1     31
# bird      19    0   903   21    23   17    10      4     2      1
# cat        7    2    17  826    20   92    18     10     3      5
# deer       2    1    12   15   929   15     7     18     1      0
# dog        3    1    10   55     8  909     2      9     1      2
# frog       7    0    12   12     2    9   956      1     0      1
# horse      2    0     3    7    12   17     1    954     1      3
# ship      19    5     2    1     2    1     0      0   960     10
# truck      5   19     1    2     0    0     1      1    10    961

# %% [markdown]
# # Compute the Accuracy, F1-Score, Precision, Recall, Support

# %%
# Create a report to show the f1-score, precision, recall
from sklearn.metrics import classification_report

report = pd.DataFrame.from_dict(classification_report(pred_vec,label_vec,output_dict=True)).T
report['Label']=[classes[int(x)] if x.isdigit() else " " for x in report.index]
report=report[['Label','f1-score','precision','recall','support']]
report
# Out:
#               Label  f1-score  precision    recall     support
# 0             plane  0.936784   0.941000  0.932607   1009.0000
# 1               car  0.964930   0.963000  0.966867    996.0000
# 2              bird  0.915357   0.903000  0.928058    973.0000
# 3               cat  0.850232   0.826000  0.875928    943.0000
# 4              deer  0.928536   0.929000  0.928072   1001.0000
# 5               dog  0.882524   0.909000  0.857547   1060.0000
# 6              frog  0.957916   0.956000  0.959839    996.0000
# 7             horse  0.954955   0.954000  0.955912    998.0000
# 8              ship  0.959041   0.960000  0.958084   1002.0000
# 9             truck  0.950544   0.961000  0.940313   1022.0000
# accuracy             0.930200   0.930200  0.930200      0.9302
# macro avg            0.930082   0.930200  0.930323  10000.0000
# weighted avg         0.930318   0.930795  0.930200  10000.0000

# %% [markdown]
# In the context of classification, 'support' refers to the number of instances or samples in a dataset that belong to a specific class. It represents the frequency or count of occurrences of each class in the dataset.
#
# Support values help assess the reliability and generalizability of classification models, as they indicate the amount of data available for each class and the potential challenges associated with imbalanced datasets.

# %% [markdown]
# # Visualize Sample Test Results
# This cell displays test images and their labels in this format: predicted (ground-truth). The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
images, labels = next(iter(test_loader))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)

# Create a 4x4 grid for displaying the images
fig, axes = plt.subplots(4, 4, figsize=(8, 8))

# Iterate over the images and display them in the grid
for idx, ax in enumerate(axes.flat):
  # Normalize the image tensor to [0, 1] range
  image = images[idx].permute(1, 2, 0)
  image = (image - image.min()) / (image.max() - image.min())
  ax.imshow(image)  # Display the image
  ax.axis('off')  # Hide the axes
  ax.set_title("{}".format(classes[preds[idx]]),
                 color=("green" if preds[idx]==labels[idx] else "red"))  # Add title to the image
plt.show()

# %% [markdown]
# #Display 50 Predicted Images
# We iterate through 50 images and plot them with their corresponding label. We will color the label in blue if our model guessed correct and in red if it failed to predict that class.

# %%
# Define the loader for all test data
test_set_all = torchvision.datasets.CIFAR10(root='./data', train=False, download=False, transform=test_transform)
test_loader_all = torch.utils.data.DataLoader(test_set_all, batch_size=128, shuffle=False, num_workers=2)


# obtain one batch of test images
dataiter = iter(test_loader_all)
images, labels = next(iter(test_loader_all))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)


fig = plt.figure(figsize=(15, 7))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for idx in range(50):
    # Normalize the image tensor to [0, 1] range
    image = images[idx].permute(1, 2, 0)
    image = (image - image.min()) / (image.max() - image.min())
    ax = fig.add_subplot(5, 10, idx + 1, xticks=[], yticks=[])
    ax.imshow(image, interpolation='nearest')

    if preds[idx]==labels[idx]:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='green')
    else:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='red')

plt.show()

# %% [markdown]
# ## Visualize wrongly classified image for each class

# %%
# Visualize wrongly classified image for each class
pred_vec_all = []
correct = 0
test_loss = 0.0

model.to(device)
model.eval()
with torch.no_grad():
    for data in test_loader_all:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        test_loss=criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec_all.append(predicted)
    pred_vec_all = torch.cat(pred_vec_all)

pred_vec_all = pred_vec_all.cpu().numpy()
ground_truths = np.asarray(test_set_all.targets)
incorrect_mask = pred_vec_all != ground_truths
incorrect_images = [test_set_all.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results_all = [pred_vec_all[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results_all[i]], fontsize=10)
    axis.imshow(incorrect_images[i], cmap='gray')
    i += 1

# %% [markdown]
# Model Architecture Summary:
#
# The model begins with comprehensive data augmentation techniques, incorporating random horizontal flips, rotations, crops, and color adjustments, which should help improve model generalization and robustness to variations in input images.The model  is built with three main layers. Each layer looks at the image in more detail than the last. The first layer picks up basic things like edges and colors using 64 filters. The second layer uses 128 filters to spot more complex patterns. The final layer uses 256 filters to understand even more complicated features in the image.
#
# To prevent the model from memorizing instead of learning,by adding dropout - which randomly turns off some parts of the model during training. the dropout increased from 0.2 to 0.5 as it go deeper into the model. Also added batch normalization, which helps the model learn more smoothly.
#
# For training, it used the Adam optimizer, which is like a smart learning engine. It starts with a learning rate of 0.001. It is a feature that reduces this learning rate when the model stops improving, helping it fine-tune its learning.
#
#
# In the beginning. I just try different optimizer like SGD,adam......and added a learning rate scheduler,  I found out adam has the heigher accuracy.  Experimenting with different dropout rates and number of layer. This setup have the best result so far. Also add Batch Norm in each layer also improve the perfermance. I found that too much  data augmentation will make the data too complex , led to lower accuracy.random horizontal flips, rotations, crops, and color adjustments, which is  balanced.
#
# Next, I added Self-attention to the model to helps each part of the image to learn from all other parts. The accuracy improved 0.2%.
