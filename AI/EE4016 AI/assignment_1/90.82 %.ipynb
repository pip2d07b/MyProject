# %% [markdown]
# # CityU EE4016: Applications of AI with Deep Learning
#
#
# ## PyTorch Multi-Layer Perceptron (MLP) Image Classifier With Fashion MNIST Dataset
#
# In this example, we will train an MLP model to classify images from the Fashion MNIST database.
#
# The Fashion MNIST dataset is a widely used dataset in Deep Learning for training and testing various algorithms. It was created as a replacement for the original handwritten digits MNIST dataset to provide a more challenging classification task.
#
# Here are some key details about the Fashion MNIST dataset:
# - The dataset consists of 70,000 grayscale images of fashion products from 10 different categories
# - Each image is a 28x28 pixel square
# - The dataset consists of a training dataset of 60,000 images and a test dataset of 10,000 images
# - In this example, the test dataset is divided into validation and test sets, each containing 5,000 samples.
#
# The goal is to classify each image into one of the 10 fashion categories, such as T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, and Ankle boot
#
# <img src='https://www.ee.cityu.edu.hk/~lmpo/ee5438/images/mlp_fmnist.png'>
#
#
# References:
# - [Image Classifier using PyTorch and Keras](https://medium.com/dataseries/image-classifier-using-pytorch-and-keras-555007a50c2e)
#
# - [Basic Syntax of the Markdown elements.](https://www.markdownguide.org/basic-syntax/)
#
# - Fashion-MNIST: https://github.com/zalandoresearch/fashion-mnist

# %% [markdown]
# # Assignment 1: Summary Report
#
# Provide your assignment report here. Write an abstract analyzing the model architecture, training process, experiments, results and evaluation conclusions. Discuss which techniques work well and how you could improve the baseline model. Include relevant visualizations.
#
# The model architecture used five fully connected layers with (512, 256, 128, 64, 10) , it increase more neurons in each layer which enable the model to learn complex function. And apply batch normalization after each hidden layer to  normalizes the inputs to each layer for each mini-batch.It can help the model to prevent overfitting. And using the ReLU activation function instead of sigmoid activation function. With these three modification the train accuracy and validation accuracy increase from 16.04% and 33.56% to 75.77% and 82.20% at the first epoch. The test set accuracy on the 5,000 test images rise from 80.40 % to 89.30 %. Test Loss is 0.57.
#
# Also,  Horizontal Flip are used as image augmentation. It simulates real-world situation. Because the item may not always positioned in the same direction.  It teaches the model to focus on key features rather than absolute positioning. And increasing the dataset size  by multiple variations of each image.
#
# For regularization, three dropout layers are applied after each activation function layer to reduces the overfitting further. And tried using dropout layer with rates of 0.3 , 0.4, 0.5 . Three dropout layers with a rate with 0.2 have a best accuracy and loss. Also changing the  optimizer  to AdamW which can based on the first and second moments of the gradients to adjust the learning rate for each parameter to improve the accuracy more.
#
# Result of 0.4 dropout layers :
# Test Loss:  0.43
# Test set Accuracy on the 5,000 test images: 89.38 %
#
# Result of 0.3 dropout layers :
# Test Loss: 0.40
# Test set Accuracy on the 5,000 test images: 89.66 %
#
# Result of 0.2 dropout layers :
# Test Loss: 0.38
# Test set Accuracy on the 5,000 test images: 90.04 %
#
# Result of 0.2 dropout layers with adamW:
# Test Loss: 0.55
# Test set Accuracy on the 5,000 test images: 90.38 %
#
#
# As a result,  More layers and neurons provide the capacity to learn complex patterns, while dropout and batch normalization help prevent overfitting that might otherwise occur with a larger model . ReLU activate function can minimize the vanishing gradient problem and increase the performance of models.  AdamW's adaptive learning rates work well with batch normalization, allowing for stable training even with deeper architectures

# %% [markdown]
# # Starting of your code

# %%
# Install the torchinfo package for showing the network architecture information
# !pip install torchinfo -qqq

# %%
# Import the necessary libraries for working with Fashion-MNIST dataset and PyTorch.
import torch
import torchvision
from torchvision import datasets,transforms
import torch.nn as nn
import torch.nn.functional as F
from torch import nn,optim,no_grad
from torch.utils.data import DataLoader
from torchinfo import summary
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import pandas as pd
import numpy as np
import pickle
import sys
import time

# %%
# To configure the usage of a GPU (cuda) or MPS (Apple) if either of them is available
has_mps = torch.backends.mps.is_built()
device = "cuda" if torch.cuda.is_available() else "mps" if has_mps else "cpu"
print(f"Python versoin: {sys.version_info.major, sys.version_info.minor, sys.version_info.micro}")
print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")
# Out:
# Python versoin: (3, 11, 9)
# PyTorch version: 2.4.1+cu118
# Device: cuda

# %%
# Set seed for reproducibility
# Students are required to use the last 4 digits of the student ID card as the seed number for Assignment 1 submission
seed = 4016
torch.manual_seed(seed)

# %% [markdown]
# # Download Fashion MNIST Dataset
#
# This code snippet creates DataLoaders to facilitate the downloading of the training and test sets. The Fashion MNIST training dataset, consisting of 60,000 samples, is used to train the Model. The test dataset is randomly split into a validation set and a test set, each containing 5,000 samples. The data loaders are employed to provide batches of data from the datasets for iteration. The training data comprises batches of images, with each image measuring 28 x 28 pixels. The corresponding labels indicate the correct Fashion labels ("T-shirt," "Trouser," "Pullover," etc.) for each image.

# %%
# Define data transformations for the training and test sets
train_transform = transforms.Compose([
     transforms.RandomHorizontalFlip(p=0.5),  # Horizontal flip with 50% probability
     transforms.ToTensor(),  # Convert images to tensors
     transforms.Normalize((0.5,), (0.5,))])  # Normalize the image data

test_transform = transforms.Compose([
     transforms.ToTensor(),  # Convert images to tensors
     transforms.Normalize((0.5,), (0.5,))])  # Normalize the image data

# Create the Fashion MNIST dataset for the training set with 60,000 images
train_set = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=train_transform)

# Create the Fashion MNIST dataset for the test set with 10,000 images
test_dataset = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=test_transform)

# Split the original test set into a validation set with 5,000 samples and a test set with 5,000 samples
val_set, test_set = torch.utils.data.random_split(test_dataset, [5000, 5000])

# Define the data loaders for the training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_set, batch_size=256, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=256, shuffle=False, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=256, shuffle=False, num_workers=2)

# Define the classes for the Fashion MNIST dataset
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ##Visualize image for each class
# The first step in a classification task is to take a look at the data, make sure it is loaded in correctly, then make any initial observations about patterns in that data.

# %%
# Visualize training image for each class
sample_images = [train_set.data[np.asarray(train_set.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i], cmap='gray')
    i += 1

# %% [markdown]
# # Define the MLP Network Architecture
#
# The following code defines a class called MLPNet which inherits from nn.Module. The network has 3 fully-connected layers:
#
# - fc1 takes the 784-pixel Fashion MNIST image as input and outputs 128 nodes
# - fc2 takes the 128 nodes and outputs 64 nodes
# - fc3 takes the 64 nodes and outputs predictions for the 10 classes
#
# The forward method defines the forward pass through the network. It applies Sigmoid activation on the first two layers and log softmax on the output layer.

# %%
## Define the MLP architecture

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(784, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(128, 64)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc5 = nn.Linear(64, 10)
        self.dropout = nn.Dropout(0.2)

        # init.xavier_uniform_(self.fc1.weight)
        # init.xavier_uniform_(self.fc2.weight)
        # init.xavier_uniform_(self.fc3.weight)

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.dropout(x)
        x = F.relu(self.bn3(self.fc3(x)))
        x = self.dropout(x)
        x = F.relu(self.bn4(self.fc4(x)))
        x = self.fc5(x)
        return F.log_softmax(x, dim=1)

# %%
model = MLP()

# %% [markdown]
# ## Print the Model Structure and Number of Parameters

# %%
summary(model=MLP(), input_size=(1, 1, 28, 28), col_width=15,
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        row_settings=['var_names'], verbose=0)
# Out:
# ====================================================================================================
# Layer (type (var_name))                  Input Shape     Output Shape    Param #         Trainable
# ====================================================================================================
# MLP (MLP)                                [1, 1, 28, 28]  [1, 10]         --              True
# ├─Linear (fc1)                           [1, 784]        [1, 512]        401,920         True
# ├─BatchNorm1d (bn1)                      [1, 512]        [1, 512]        1,024           True
# ├─Dropout (dropout)                      [1, 512]        [1, 512]        --              --
# ├─Linear (fc2)                           [1, 512]        [1, 256]        131,328         True
# ├─BatchNorm1d (bn2)                      [1, 256]        [1, 256]        512             True
# ├─Dropout (dropout)                      [1, 256]        [1, 256]        --              --
# ├─Linear (fc3)                           [1, 256]        [1, 128]        32,896          True
# ├─BatchNorm1d (bn3)                      [1, 128]        [1, 128]        256             True
# ├─Dropout (dropout)                      [1, 128]        [1, 128]        --              --
# ├─Linear (fc4)                           [1, 128]        [1, 64]         8,256           True
# ├─BatchNorm1d (bn4)                      [1, 64]         [1, 64]         128             True
# ├─Linear (fc5)                           [1, 64]         [1, 10]         650             True
# ====================================================================================================
# Total params: 576,970
# Trainable params: 576,970
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.58
# ====================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 2.31
# Estimated Total Size (MB): 2.33
# ====================================================================================================

# %% [markdown]
# ## Specify Loss Function and Optimizer
# It's recommended that you use cross-entropy loss for classification. If you look at the documentation, you can see that PyTorch's cross entropy function applies a softmax funtion to the output layer and then calculates the log loss.

# %%
# Specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# Specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = optim.AdamW(model.parameters(), lr=0.01, weight_decay=1e-5)

# Specify Adam optimizer with defualt setting
# optimizer = optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)

# Specify learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

# %% [markdown]
# ##Training the Network
# The steps for training/learning from a batch of data are described in the comments below:
#
# Clear the gradients of all optimized variables Forward pass: compute predicted outputs by passing inputs to the model Calculate the loss Backward pass: compute gradient of the loss with respect to model parameters Perform a single optimization step (parameter update) Update average training loss The following loop trains for 100 epochs; take a look at how the values for the training loss decrease over time. We want it to decrease while also avoiding overfitting the training data.

# %%
# Create a Models folder to store the checkpoints
# !mkdir Models
# Out:
# �l�ؿ����ɮ� Models �w�g�s�b�C

# %%
EPOCHS = 100

loss_hist, acc_hist = [], []  # Lists to store training loss and accuracy
loss_hist_val, acc_hist_val = [], []  # Lists to store validation loss and accuracy

model.to(device)  # Move the model to the specified device (e.g., GPU)

print("Training was started.\n")

for epoch in range(1, EPOCHS + 1):
    time_ckpt = time.time()
    print("EPOCH:", epoch, end=" ")
    running_loss = 0.0
    correct = 0

    # Training loop
    for data in train_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)

        optimizer.zero_grad()  # Clear the gradients
        outputs = model(batch)  # Forward pass
        loss = criterion(outputs, labels)  # Compute the loss
        loss.backward()  # Backward pass (compute gradients)
        optimizer.step()  # Update the model's parameters

        # Compute training statistics
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

    avg_loss = running_loss / len(train_set)  # Average training loss for the epoch
    avg_acc = correct / len(train_set)  # Average training accuracy for the epoch
    loss_hist.append(avg_loss)
    acc_hist.append(avg_acc)

    # Validation statistics
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        loss_val = 0.0
        correct_val = 0

        # Validation loop
        for data in val_loader:
            batch, labels = data
            batch, labels = batch.to(device), labels.to(device)
            outputs = model(batch)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == labels).sum().item()
            loss_val += loss.item()

        avg_loss_val = loss_val / len(val_set)  # Average validation loss for the epoch
        avg_acc_val = correct_val / len(val_set)  # Average validation accuracy for the epoch
        loss_hist_val.append(avg_loss_val)
        acc_hist_val.append(avg_acc_val)

    model.train()  # Set the model back to training mode
    scheduler.step(avg_loss_val) # Check the scheduler for updating the learning rate

    # Save the model at the end of each epoch
    with open("Models/MLP_model_{}.pth".format(epoch), "wb") as f:
        model.eval()
        pickle.dump(model, f)
        model.train()

    print("Train Loss: {:.3f}".format(avg_loss * 100), end=" ")
    print("Val Loss: {:.3f}".format(avg_loss_val * 100), end=" ")
    print("Train Accuracy: {:.2f}%".format(avg_acc * 100), end=" ")
    print("Val Accuracy: {:.2f}%".format(avg_acc_val * 100), end=" ")
    print("Time: {:.2f}s".format(time.time() - time_ckpt), end=" \n")
# Out:
# Training was started.
#
# EPOCH: 1 Train Loss: 0.223 Val Loss: 0.181 Train Accuracy: 79.54% Val Accuracy: 83.60% Time: 7.58s
# EPOCH: 2 Train Loss: 0.164 Val Loss: 0.173 Train Accuracy: 84.70% Val Accuracy: 84.04% Time: 7.52s
# EPOCH: 3 Train Loss: 0.150 Val Loss: 0.147 Train Accuracy: 85.97% Val Accuracy: 86.44% Time: 7.47s
# EPOCH: 4 Train Loss: 0.141 Val Loss: 0.143 Train Accuracy: 86.89% Val Accuracy: 86.66% Time: 7.85s
# EPOCH: 5 Train Loss: 0.134 Val Loss: 0.146 Train Accuracy: 87.65% Val Accuracy: 86.68% Time: 7.58s
# EPOCH: 6 Train Loss: 0.128 Val Loss: 0.154 Train Accuracy: 88.02% Val Accuracy: 85.62% Time: 7.59s
# EPOCH: 7 Train Loss: 0.124 Val Loss: 0.144 Train Accuracy: 88.37% Val Accuracy: 86.82% Time: 7.59s
# EPOCH: 8 Train Loss: 0.119 Val Loss: 0.130 Train Accuracy: 88.76% Val Accuracy: 88.06% Time: 7.46s
# EPOCH: 9 Train Loss: 0.114 Val Loss: 0.130 Train Accuracy: 89.42% Val Accuracy: 88.16% Time: 7.54s
# EPOCH: 10 Train Loss: 0.113 Val Loss: 0.126 Train Accuracy: 89.46% Val Accuracy: 88.34% Time: 7.40s
# EPOCH: 11 Train Loss: 0.110 Val Loss: 0.135 Train Accuracy: 89.76% Val Accuracy: 87.82% Time: 7.53s
# EPOCH: 12 Train Loss: 0.106 Val Loss: 0.127 Train Accuracy: 90.02% Val Accuracy: 88.42% Time: 7.57s
# EPOCH: 13 Train Loss: 0.103 Val Loss: 0.132 Train Accuracy: 90.20% Val Accuracy: 87.50% Time: 7.51s
# EPOCH: 14 Train Loss: 0.103 Val Loss: 0.126 Train Accuracy: 90.26% Val Accuracy: 88.38% Time: 7.42s
# EPOCH: 15 Train Loss: 0.099 Val Loss: 0.129 Train Accuracy: 90.56% Val Accuracy: 88.36% Time: 7.48s
# EPOCH: 16 Train Loss: 0.098 Val Loss: 0.125 Train Accuracy: 90.70% Val Accuracy: 88.74% Time: 7.52s
# EPOCH: 17 Train Loss: 0.095 Val Loss: 0.120 Train Accuracy: 90.98% Val Accuracy: 89.70% Time: 7.54s
# EPOCH: 18 Train Loss: 0.094 Val Loss: 0.124 Train Accuracy: 91.12% Val Accuracy: 89.38% Time: 7.82s
# EPOCH: 19 Train Loss: 0.092 Val Loss: 0.122 Train Accuracy: 91.34% Val Accuracy: 89.18% Time: 7.73s
# EPOCH: 20 Train Loss: 0.090 Val Loss: 0.119 Train Accuracy: 91.40% Val Accuracy: 89.36% Time: 7.58s
# EPOCH: 21 Train Loss: 0.089 Val Loss: 0.126 Train Accuracy: 91.47% Val Accuracy: 88.78% Time: 7.55s
# EPOCH: 22 Train Loss: 0.087 Val Loss: 0.125 Train Accuracy: 91.65% Val Accuracy: 89.32% Time: 7.63s
# EPOCH: 23 Train Loss: 0.085 Val Loss: 0.134 Train Accuracy: 92.08% Val Accuracy: 88.44% Time: 7.64s
# EPOCH: 24 Train Loss: 0.083 Val Loss: 0.120 Train Accuracy: 92.09% Val Accuracy: 89.80% Time: 7.70s
# EPOCH: 25 Train Loss: 0.082 Val Loss: 0.122 Train Accuracy: 92.17% Val Accuracy: 89.76% Time: 7.81s
# EPOCH: 26 Train Loss: 0.082 Val Loss: 0.123 Train Accuracy: 92.21% Val Accuracy: 89.70% Time: 7.75s
# EPOCH: 27 Train Loss: 0.069 Val Loss: 0.116 Train Accuracy: 93.42% Val Accuracy: 90.32% Time: 7.65s
# EPOCH: 28 Train Loss: 0.063 Val Loss: 0.116 Train Accuracy: 93.96% Val Accuracy: 90.28% Time: 7.68s
# EPOCH: 29 Train Loss: 0.061 Val Loss: 0.118 Train Accuracy: 94.23% Val Accuracy: 90.40% Time: 7.63s
# EPOCH: 30 Train Loss: 0.058 Val Loss: 0.119 Train Accuracy: 94.47% Val Accuracy: 90.52% Time: 7.92s
# EPOCH: 31 Train Loss: 0.058 Val Loss: 0.117 Train Accuracy: 94.51% Val Accuracy: 90.66% Time: 7.93s
# EPOCH: 32 Train Loss: 0.056 Val Loss: 0.119 Train Accuracy: 94.71% Val Accuracy: 90.48% Time: 7.55s
# EPOCH: 33 Train Loss: 0.056 Val Loss: 0.121 Train Accuracy: 94.62% Val Accuracy: 90.48% Time: 7.69s
# EPOCH: 34 Train Loss: 0.054 Val Loss: 0.120 Train Accuracy: 94.88% Val Accuracy: 90.56% Time: 8.03s
# EPOCH: 35 Train Loss: 0.053 Val Loss: 0.120 Train Accuracy: 94.95% Val Accuracy: 90.64% Time: 7.74s
# EPOCH: 36 Train Loss: 0.053 Val Loss: 0.120 Train Accuracy: 95.01% Val Accuracy: 90.54% Time: 7.55s
# EPOCH: 37 Train Loss: 0.053 Val Loss: 0.120 Train Accuracy: 94.86% Val Accuracy: 90.48% Time: 7.91s
# EPOCH: 38 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.05% Val Accuracy: 90.68% Time: 7.78s
# EPOCH: 39 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.97% Val Accuracy: 90.70% Time: 7.61s
# EPOCH: 40 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.05% Val Accuracy: 90.62% Time: 7.49s
# EPOCH: 41 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.03% Val Accuracy: 90.74% Time: 7.44s
# EPOCH: 42 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.06% Val Accuracy: 90.72% Time: 7.71s
# EPOCH: 43 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 94.93% Val Accuracy: 90.52% Time: 7.65s
# EPOCH: 44 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.95% Val Accuracy: 90.70% Time: 7.72s
# EPOCH: 45 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.92% Val Accuracy: 90.60% Time: 7.93s
# EPOCH: 46 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 94.99% Val Accuracy: 90.52% Time: 7.62s
# EPOCH: 47 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.02% Val Accuracy: 90.58% Time: 7.45s
# EPOCH: 48 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.10% Val Accuracy: 90.70% Time: 7.46s
# EPOCH: 49 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 94.94% Val Accuracy: 90.60% Time: 7.58s
# EPOCH: 50 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.90% Val Accuracy: 90.64% Time: 7.61s
# EPOCH: 51 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.08% Val Accuracy: 90.60% Time: 7.49s
# EPOCH: 52 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.04% Val Accuracy: 90.56% Time: 7.43s
# EPOCH: 53 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 94.98% Val Accuracy: 90.70% Time: 7.47s
# EPOCH: 54 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.56% Time: 7.46s
# EPOCH: 55 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.96% Val Accuracy: 90.76% Time: 7.57s
# EPOCH: 56 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 94.97% Val Accuracy: 90.76% Time: 7.51s
# EPOCH: 57 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.95% Val Accuracy: 90.62% Time: 7.41s
# EPOCH: 58 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.08% Val Accuracy: 90.68% Time: 7.46s
# EPOCH: 59 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.99% Val Accuracy: 90.68% Time: 7.78s
# EPOCH: 60 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.03% Val Accuracy: 90.66% Time: 7.64s
# EPOCH: 61 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.00% Val Accuracy: 90.68% Time: 7.73s
# EPOCH: 62 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.97% Val Accuracy: 90.82% Time: 7.58s
# EPOCH: 63 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.87% Val Accuracy: 90.72% Time: 7.56s
# EPOCH: 64 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.76% Time: 7.38s
# EPOCH: 65 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 94.95% Val Accuracy: 90.56% Time: 7.50s
# EPOCH: 66 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.04% Val Accuracy: 90.60% Time: 7.44s
# EPOCH: 67 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.94% Val Accuracy: 90.74% Time: 7.38s
# EPOCH: 68 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.68% Time: 7.42s
# EPOCH: 69 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.74% Time: 7.53s
# EPOCH: 70 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.00% Val Accuracy: 90.50% Time: 7.51s
# EPOCH: 71 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.03% Val Accuracy: 90.68% Time: 7.38s
# EPOCH: 72 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.92% Val Accuracy: 90.56% Time: 7.41s
# EPOCH: 73 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.03% Val Accuracy: 90.58% Time: 7.57s
# EPOCH: 74 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.02% Val Accuracy: 90.58% Time: 7.50s
# EPOCH: 75 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 94.96% Val Accuracy: 90.62% Time: 7.58s
# EPOCH: 76 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.06% Val Accuracy: 90.66% Time: 7.46s
# EPOCH: 77 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.01% Val Accuracy: 90.82% Time: 7.43s
# EPOCH: 78 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 94.95% Val Accuracy: 90.60% Time: 7.52s
# EPOCH: 79 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 94.90% Val Accuracy: 90.56% Time: 7.80s
# EPOCH: 80 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.91% Val Accuracy: 90.80% Time: 7.63s
# EPOCH: 81 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.01% Val Accuracy: 90.66% Time: 7.69s
# EPOCH: 82 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 94.94% Val Accuracy: 90.82% Time: 7.53s
# EPOCH: 83 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.02% Val Accuracy: 90.56% Time: 7.51s
# EPOCH: 84 Train Loss: 0.051 Val Loss: 0.121 Train Accuracy: 95.06% Val Accuracy: 90.64% Time: 7.39s
# EPOCH: 85 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 95.04% Val Accuracy: 90.78% Time: 7.52s
# EPOCH: 86 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.66% Time: 7.43s
# EPOCH: 87 Train Loss: 0.052 Val Loss: 0.122 Train Accuracy: 95.08% Val Accuracy: 90.56% Time: 7.50s
# EPOCH: 88 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 95.02% Val Accuracy: 90.68% Time: 7.78s
# EPOCH: 89 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.84% Val Accuracy: 90.86% Time: 7.66s
# EPOCH: 90 Train Loss: 0.053 Val Loss: 0.122 Train Accuracy: 95.01% Val Accuracy: 90.64% Time: 7.60s
# EPOCH: 91 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.93% Val Accuracy: 90.84% Time: 7.46s
# EPOCH: 92 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 94.99% Val Accuracy: 90.70% Time: 7.54s
# EPOCH: 93 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.91% Val Accuracy: 90.60% Time: 7.58s
# EPOCH: 94 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.95% Val Accuracy: 90.64% Time: 7.46s
# EPOCH: 95 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 95.07% Val Accuracy: 90.74% Time: 7.54s
# EPOCH: 96 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 94.97% Val Accuracy: 90.58% Time: 7.75s
# EPOCH: 97 Train Loss: 0.052 Val Loss: 0.121 Train Accuracy: 94.98% Val Accuracy: 90.66% Time: 7.58s
# EPOCH: 98 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 95.06% Val Accuracy: 90.62% Time: 7.55s
# EPOCH: 99 Train Loss: 0.052 Val Loss: 0.120 Train Accuracy: 94.99% Val Accuracy: 90.62% Time: 7.57s
# EPOCH: 100 Train Loss: 0.053 Val Loss: 0.121 Train Accuracy: 94.99% Val Accuracy: 90.62% Time: 7.52s

# %% [markdown]
# ## Plotting Training Statistics
#
# Loss is a function of the difference of the network output and the target values. We are minimizing the loss function during training so it should decrease over time. Accuracy is the classification accuracy for the test data.

# %%
plots=[(loss_hist,loss_hist_val),(acc_hist,acc_hist_val)]
plt_labels=[("Training Loss","Validation Loss"),("Training Accuracy","Validation Accuracy")]
plt_titles=["Loss","Accuracy"]
plt.figure(figsize=(20,7))
for i in range(0,2):
    ax=plt.subplot(1,2,i+1)
    ax.plot(plots[i][0],label=plt_labels[i][0])
    ax.plot(plots[i][1],label=plt_labels[i][1])
    ax.set_title(plt_titles[i])
    ax.legend()

# %% [markdown]
# ##Save the trained model

# %%
# from google.colab import files
# torch.save(model.state_dict(), 'checkpoint.pth')
# # download checkpoint file
# files.download('checkpoint.pth')
# model.load_state_dict(torch.load('checkpoint.pth'))

# %%
# Selecting the best model
best_acc = max(acc_hist_val)
best_epoch = acc_hist_val.index(best_acc)+1

print("Best accuracy on validation set: {:.2f}%".format(best_acc*100))
print("Best epoch: {}".format(best_epoch))

# Load the best model
with open(f"Models/MLP_model_{best_epoch}.pth","rb") as f:
    model=pickle.load(f)
# Out:
# Best accuracy on validation set: 90.86%
# Best epoch: 89

# %% [markdown]
# #Compute Test Set Accuracy using the Trained Model
#
# While it is important to achieve high training and validation accuracy, these metrics can sometimes be deceptive due to overfitting. On the other hand, the test accuracy provides a more reliable assessment of how well the model performs on new, unseen data, which is crucial for real-world applications.
#
# Hence, it is essential to evaluate the performance of our best model by testing it on previously unseen data. This allows us to determine how effectively the model generalizes. Furthermore, **in the marking scheme of Assignment 1, emphasis is placed primarily on the test set accuracy of the model**, rather than the training or validation accuracy.

# %%
pred_vec = []
label_vec = []
correct = 0
test_loss = 0.0

model.to(device)
model.eval()

with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        test_loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec.extend(predicted.cpu().numpy())  # Convert tensor to numpy array
        label_vec.extend(labels.cpu().numpy())  # Convert tensor to numpy array

pred_vec = np.array(pred_vec)
label_vec = np.array(label_vec)

print("Test Loss: {:.2f}".format(test_loss))
print('Test set Accuracy on the 5,000 test images: %.2f %%' % (100 * correct / len(test_set)))
# Out:
# Test Loss: 0.36
# Test set Accuracy on the 5,000 test images: 90.82 %

# %% [markdown]
# # Display the Confusion Matrix

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(label_vec, pred_vec)
# Convert confusion matrix to pandas DataFrame
labels = np.unique(label_vec)
confusion_df = pd.DataFrame(confusion_mat, index=classes, columns=classes)
print("Confusion Matrix")
confusion_df
# Out:
# Confusion Matrix
#              T-shirt/top  Trouser  Pullover  Dress  Coat  Sandal  Shirt  \
# T-shirt/top          437        1         4      6     2       0     52
# Trouser                0      487         0      8     0       0      2
# Pullover               7        0       453      3    45       0     22
# Dress                  7        2         5    446     9       0      8
# Coat                   0        0        28     12   438       0     25
# Sandal                 0        0         0      0     0     491      0
# Shirt                 52        0        36     13    27       0    345
# Sneaker                0        0         0      0     0       4      0
# Bag                    2        0         3      0     1       1      0
# Ankle boot             0        0         0      0     0       4      0
#
#              Sneaker  Bag  Ankle boot
# T-shirt/top        0    3           0
# Trouser            0    1           0
# Pullover           0    1           0
# Dress              0    1           0
# Coat               0    1           0
# Sandal            11    0           5
# Shirt              0    5           0
# Sneaker          488    0          14
# Bag                2  482           0
# Ankle boot        24    0         474

# %% [markdown]
# # Compute the Accuracy, F1-Score, Precision, Recall, Support

# %%
# Create a report to show the f1-score, precision, recall
from sklearn.metrics import classification_report

report = pd.DataFrame.from_dict(classification_report(pred_vec,label_vec,output_dict=True)).T
report['Label']=[classes[int(x)] if x.isdigit() else " " for x in report.index]
report=report[['Label','f1-score','precision','recall','support']]
report
# Out:
#                     Label  f1-score  precision    recall    support
# 0             T-shirt/top  0.865347   0.865347  0.865347   505.0000
# 1                 Trouser  0.985830   0.977912  0.993878   490.0000
# 2                Pullover  0.854717   0.853107  0.856333   529.0000
# 3                   Dress  0.923395   0.933054  0.913934   488.0000
# 4                    Coat  0.853801   0.869048  0.839080   522.0000
# 5                  Sandal  0.975174   0.968442  0.982000   500.0000
# 6                   Shirt  0.740343   0.721757  0.759912   454.0000
# 7                 Sneaker  0.946654   0.964427  0.929524   525.0000
# 8                     Bag  0.978680   0.981670  0.975709   494.0000
# 9              Ankle boot  0.952764   0.944223  0.961460   493.0000
# accuracy                   0.908200   0.908200  0.908200     0.9082
# macro avg                  0.907670   0.907899  0.907718  5000.0000
# weighted avg               0.908476   0.909023  0.908200  5000.0000

# %% [markdown]
# In the context of classification, 'support' refers to the number of instances or samples in a dataset that belong to a specific class. It represents the frequency or count of occurrences of each class in the dataset.
#
# Support values help assess the reliability and generalizability of classification models, as they indicate the amount of data available for each class and the potential challenges associated with imbalanced datasets.

# %% [markdown]
# # Visualize Sample Test Results
# This cell displays test images and their labels in this format: predicted (ground-truth). The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
images, labels = next(iter(test_loader))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)

# Create a 4x4 grid for displaying the images
fig, axes = plt.subplots(4, 4, figsize=(8, 8))

# Iterate over the images and display them in the grid
for idx, ax in enumerate(axes.flat):
  # Normalize the image tensor to [0, 1] range
  image = images[idx].permute(1, 2, 0)
  image = (image - image.min()) / (image.max() - image.min())
  ax.imshow(image, cmap='gray')  # Display the image
  ax.axis('off')  # Hide the axes
  ax.set_title("{}".format(classes[preds[idx]]),
                 color=("green" if preds[idx]==labels[idx] else "red"))  # Add title to the image
plt.show()

# %% [markdown]
# #Display 50 Predicted Images in Reversed Grayscale
# We iterate through 50 images and plot them with their corresponding label. We will color the label in blue if our model guessed correct and in red if it failed to predict that class.

# %%
# Define the loader for all test data
test_set_all = torchvision.datasets.FashionMNIST(root='./data', train=False, download=False, transform=test_transform)
test_loader_all = torch.utils.data.DataLoader(test_set_all, batch_size=128, shuffle=False, num_workers=2)


# obtain one batch of test images
dataiter = iter(test_loader_all)
images, labels = next(iter(test_loader_all))
model.cpu()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)


fig = plt.figure(figsize=(15, 7))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for idx in range(50):
    # Normalize the image tensor to [0, 1] range
    image = images[idx].permute(1, 2, 0)
    image = (image - image.min()) / (image.max() - image.min())
    ax = fig.add_subplot(5, 10, idx + 1, xticks=[], yticks=[])
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')

    if preds[idx]==labels[idx]:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='green')
    else:
      ax.text(0, 3, str(classes[preds[idx].item()]), color='red')

plt.show()

# %% [markdown]
# #Visualize wrongly classified image for each class

# %%
# Visualize wrongly classified image for each class


pred_vec_all = []
correct = 0
test_loss = 0.0

model.to(device)

with torch.no_grad():
    for data in test_loader_all:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = model(batch)
        test_loss=criterion(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec_all.append(predicted)
    pred_vec_all = torch.cat(pred_vec_all)

pred_vec_all = pred_vec_all.cpu().numpy()
ground_truths = np.asarray(test_set_all.targets)
incorrect_mask = pred_vec_all != ground_truths
incorrect_images = [test_set_all.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results_all = [pred_vec_all[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results_all[i]], fontsize=10)
    axis.imshow(incorrect_images[i], cmap='gray')
    i += 1
